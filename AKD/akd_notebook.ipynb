# %%
import sys
from tqdm import tqdm
import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, accuracy_score

from ncf.ncf import NCF
from ncf.dataset import Dataset as NCFDataset

import torch
import torch.nn as nn
import torch.nn.functional as F

import warnings
warnings.filterwarnings('ignore')

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]
# Pandas version: 2.2.1
# Tensorflow version: 2.16.1

# %%
SEED = 42

PATH = f'C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/generated_data/'
EMBEDDINGS_PATH = 'C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/embeddings'

DATA_PATH =  PATH + 'united_data_embeddings.csv'
ENCODED_PATH = PATH + 'united_data_encoded_embeddings.csv'
ENCODED_SPLIT_PATH = PATH + 'akd_united_split_set'

train_file = PATH + f'akd_train_{SEED}.csv'
test_file = PATH + f'akd_test_{SEED}.csv'

# %% [markdown]
# # Train/Test Split

# %%
df = pd.read_csv(ENCODED_PATH, index_col=0)

df.head()
# Out:
#    conceptA  conceptB  isPrerequisite dataset  file  conceptA_ind  \
# 0      1076      1562               1  moocML  mooc           128
# 1      1347       855               1  moocML  mooc           160
# 2      1347       516               0  moocML  mooc           160
# 3      1347      1274               0  moocML  mooc           160
# 4      1347       443               0  moocML  mooc           160
#
#    conceptB_ind
# 0           160
# 1           417
# 2           101
# 3           301
# 4           120

# %%
df['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
concepts = list(set(list(df['conceptA']) + list(df['conceptB'])))

# %%
train, test = train_test_split(df, test_size=0.2, random_state=SEED, stratify=df['dataset'])

# %%
df.loc[train.index, '_split_set'] = 'train'
df.loc[test.index, '_split_set'] = 'test'

# %%
df.head()
# Out:
#    conceptA  conceptB  isPrerequisite dataset  file  conceptA_ind  \
# 0      1076      1562               1  moocML  mooc           128
# 1      1347       855               1  moocML  mooc           160
# 2      1347       516               0  moocML  mooc           160
# 3      1347      1274               0  moocML  mooc           160
# 4      1347       443               0  moocML  mooc           160
#
#    conceptB_ind _split_set
# 0           160      train
# 1           417      train
# 2           101       test
# 3           301      train
# 4           120      train

# %%
train.shape, test.shape
# Out:
# ((14862, 7), (3716, 7))

# %%
train_conceptA = list(set(list(train['conceptA'])))
train_conceptB = list(set(list(train['conceptB'])))
test_conceptA = list(set(list(test['conceptA'])))
test_conceptB = list(set(list(test['conceptB'])))

# %%
train['dataset'].value_counts() / test['dataset'].value_counts()
# Out:
# dataset
# moocML     3.997766
# al_cpl     3.999234
# drive      4.003578
# moocDSA    4.000000
# Name: count, dtype: float64

# %%
a = [x for x in test_conceptA if x not in train_conceptA]
b = [x for x in test_conceptB if x not in train_conceptB]

# %%
maskA = test['conceptA'].isin(a)
maskB = test['conceptB'].isin(b)

# %%
train = pd.concat([train, test[maskA | maskB]], axis=0)
test.drop(index=test[maskA | maskB].index, inplace=True)

# %%
train.shape, test.shape
# Out:
# ((14958, 7), (3620, 7))

# %%
train.sort_values(by=['conceptA']).to_csv(train_file, index=False)
test.sort_values(by=['conceptA']).to_csv(test_file, index=False)

df.to_csv(ENCODED_SPLIT_PATH, index=False)

# %% [markdown]
# # Generate Train Set For Tensor

# %%
# Load the train, test set
train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

# Load the embedding dataframes
embedding_dfs = {
    'al_cpl': pd.read_csv(EMBEDDINGS_PATH + r'\al_cpl_embeddings_mistral.csv'),
    'drive': pd.read_csv(EMBEDDINGS_PATH + r'\drive_embeddings_mistral.csv'),
    'mooc': pd.read_csv(EMBEDDINGS_PATH + r'\mooc_embeddings_mistral.csv')
}

# Function to get embedding for a concept
def get_embedding(file, concept_ind):
    embedding = embedding_dfs[file].loc[concept_ind].iloc[1:].values
    return embedding

# Function to process a dataset
def process_dataset(df):
    x_list = []
    y_list = []

    for _, row in df.iterrows():
        file = row['file']
        
        # Get embeddings for conceptA and conceptB
        embedding_a = get_embedding(file, row['conceptA_ind'])
        embedding_b = get_embedding(file, row['conceptB_ind'])
        
        # Combine the embeddings
        combined_features = np.concatenate([embedding_a, embedding_b])
        
        x_list.append(combined_features)
        y_list.append(row['isPrerequisite'])

    return x_list, y_list

# Process train and test sets
x_train_list, y_train_list = process_dataset(train)
x_test_list, y_test_list = process_dataset(test)

# Convert to PyTorch tensors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

x_train = torch.tensor(x_train_list, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train_list, dtype=torch.long).to(device)

x_test = torch.tensor(x_test_list, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test_list, dtype=torch.long).to(device)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: torch.Size([14958, 2048])
# y_train shape: torch.Size([14958])
# x_test shape: torch.Size([3620, 2048])
# y_test shape: torch.Size([3620])

# %% [markdown]
# # Content-Based Learning

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_size):
        super(BinaryClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)  # Fully connected layer 1
        self.dropout1 = nn.Dropout(0.8)         # Dropout layer with 20% probability
        self.fc2 = nn.Linear(512, 256)          # Fully connected layer 2
        self.dropout2 = nn.Dropout(0.8)         # Dropout layer with 20% probability
        self.fc3 = nn.Linear(256, 1)            # Output layer
        
    def forward(self, x):
        x = F.relu(self.fc1(x))       # Apply ReLU activation to the first fully connected layer
        x = self.dropout1(x)          # Apply dropout to the output of the first layer
        x = F.relu(self.fc2(x))       # Apply ReLU activation to the second fully connected layer
        x = self.dropout2(x)          # Apply dropout to the output of the second layer
        x = torch.sigmoid(self.fc3(x))  # Apply sigmoid activation to the output layer for binary classification
        return x

# %%
# Assuming x_train is your input tensor
input_size = x_train.shape[1]  # This should be 2048 (1024 * 2) based on your previous code

# Initialize the model
model = BinaryClassifier(input_size)

# Move the model to the same device as your data
model = model.to(device)

# Define loss function and optimizer
criterion = nn.BCELoss()  # Binary Cross Entropy Loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop (simplified)
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    outputs = model(x_train)
    loss = criterion(outputs, y_train.float().unsqueeze(1))
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        model.eval()  # Set the model to evaluation mode
        train_preds = (outputs >= 0.5).float()  # Convert probabilities to binary predictions
        train_acc = accuracy_score(y_train.cpu().numpy(), train_preds.cpu().numpy())
        train_f1 = f1_score(y_train.cpu().numpy(), train_preds.cpu().numpy())

    with torch.no_grad():
        test_outputs = model(x_test)
        test_preds = (test_outputs >= 0.5).float()  # Convert probabilities to binary predictions
        test_acc = accuracy_score(y_test.cpu().numpy(), test_preds.cpu().numpy())
        test_f1 = f1_score(y_test.cpu().numpy(), test_preds.cpu().numpy())

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Train Accuracy: {train_acc:.4f}, Train F1: {train_f1:.4f}, Test Accuracy: {test_acc:.4f}, Test F1: {test_f1:.4f}')

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/500], Loss: 0.6825, Train Accuracy: 0.6981, Train F1: 0.0572, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [1/500], Loss: 0.6825
# Epoch [2/500], Loss: 0.6621, Train Accuracy: 0.7127, Train F1: 0.0005, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [2/500], Loss: 0.6621
# Epoch [3/500], Loss: 0.6384, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [3/500], Loss: 0.6384
# Epoch [4/500], Loss: 0.6156, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [4/500], Loss: 0.6156
# Epoch [5/500], Loss: 0.6045, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [5/500], Loss: 0.6045
# Epoch [6/500], Loss: 0.6150, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [6/500], Loss: 0.6150
# Epoch [7/500], Loss: 0.6217, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [7/500], Loss: 0.6217
# Epoch [8/500], Loss: 0.6142, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [8/500], Loss: 0.6142
# Epoch [9/500], Loss: 0.6052, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [9/500], Loss: 0.6052
# Epoch [10/500], Loss: 0.6005, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [10/500], Loss: 0.6005
# Epoch [11/500], Loss: 0.6003, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [11/500], Loss: 0.6003
# Epoch [12/500], Loss: 0.6026, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [12/500], Loss: 0.6026
# Epoch [13/500], Loss: 0.6035, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [13/500], Loss: 0.6035
# Epoch [14/500], Loss: 0.6022, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [14/500], Loss: 0.6022
# Epoch [15/500], Loss: 0.6003, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [15/500], Loss: 0.6003
# Epoch [16/500], Loss: 0.5990, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [16/500], Loss: 0.5990
# Epoch [17/500], Loss: 0.5956, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [17/500], Loss: 0.5956
# Epoch [18/500], Loss: 0.5924, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [18/500], Loss: 0.5924
# Epoch [19/500], Loss: 0.5909, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [19/500], Loss: 0.5909
# Epoch [20/500], Loss: 0.5940, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [20/500], Loss: 0.5940
# Epoch [21/500], Loss: 0.5914, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [21/500], Loss: 0.5914
# Epoch [22/500], Loss: 0.5897, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [22/500], Loss: 0.5897
# Epoch [23/500], Loss: 0.5883, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [23/500], Loss: 0.5883
# Epoch [24/500], Loss: 0.5856, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [24/500], Loss: 0.5856
# Epoch [25/500], Loss: 0.5832, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [25/500], Loss: 0.5832
# Epoch [26/500], Loss: 0.5817, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [26/500], Loss: 0.5817
# Epoch [27/500], Loss: 0.5808, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch
# Epoch [488/500], Loss: 0.0973
# Epoch [489/500], Loss: 0.0947, Train Accuracy: 0.9636, Train F1: 0.9371, Test Accuracy: 0.8972, Test F1: 0.8084
# Epoch [489/500], Loss: 0.0947
# Epoch [490/500], Loss: 0.0929, Train Accuracy: 0.9628, Train F1: 0.9356, Test Accuracy: 0.8997, Test F1: 0.8139
# Epoch [490/500], Loss: 0.0929
# Epoch [491/500], Loss: 0.0951, Train Accuracy: 0.9633, Train F1: 0.9364, Test Accuracy: 0.8978, Test F1: 0.8089
# Epoch [491/500], Loss: 0.0951
# Epoch [492/500], Loss: 0.0936, Train Accuracy: 0.9628, Train F1: 0.9356, Test Accuracy: 0.8989, Test F1: 0.8092
# Epoch [492/500], Loss: 0.0936
# Epoch [493/500], Loss: 0.0930, Train Accuracy: 0.9640, Train F1: 0.9371, Test Accuracy: 0.8989, Test F1: 0.8133
# Epoch [493/500], Loss: 0.0930
# Epoch [494/500], Loss: 0.0946, Train Accuracy: 0.9632, Train F1: 0.9362, Test Accuracy: 0.9014, Test F1: 0.8200
# Epoch [494/500], Loss: 0.0946
# Epoch [495/500], Loss: 0.0946, Train Accuracy: 0.9626, Train F1: 0.9361, Test Accuracy: 0.8975, Test F1: 0.8081
# Epoch [495/500], Loss: 0.0946
# Epoch [496/500], Loss: 0.0956, Train Accuracy: 0.9639, Train F1: 0.9372, Test Accuracy: 0.9006, Test F1: 0.8160
# Epoch [496/500], Loss: 0.0956
# Epoch [497/500], Loss: 0.0928, Train Accuracy: 0.9633, Train F1: 0.9366, Test Accuracy: 0.9000, Test F1: 0.8157
# Epoch [497/500], Loss: 0.0928
# Epoch [498/500], Loss: 0.0920, Train Accuracy: 0.9630, Train F1: 0.9362, Test Accuracy: 0.9008, Test F1: 0.8167
# Epoch [498/500], Loss: 0.0920
# Epoch [499/500], Loss: 0.0975, Train Accuracy: 0.9601, Train F1: 0.9312, Test Accuracy: 0.8994, Test F1: 0.8108
# Epoch [499/500], Loss: 0.0975
# Epoch [500/500], Loss: 0.0948, Train Accuracy: 0.9608, Train F1: 0.9315, Test Accuracy: 0.8989, Test F1: 0.8119
# Epoch [500/500], Loss: 0.0948

# %% [markdown]
# # Graph-Based Learning

# %%
data = NCFDataset(train_file=train_file, seed=SEED, col_user='conceptA', col_item='conceptB')
# Out:
# INFO:ncf.dataset:Indexing C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/generated_data/akd_train_42.csv ...

# %%
data.n_users, data.n_items
# Out:
# (1384, 1600)

# %%
model = NCF(
    n_users=data.n_users, 
    n_items=data.n_items,
    model_type="NeuMF",
    n_factors=16,
    layer_sizes=[8,4],
    n_epochs=20,    
    batch_size=256,
    learning_rate=0.001,
    verbose=20, 
    seed=SEED
)

# %%
# %%time

model.fit(data)
# Out:
# INFO:ncf.ncf:Epoch 20 [4.52s]: train_loss = 0.035806
# CPU times: total: 1min 4s
# Wall time: 1min 6s

# %%
THRESHOLD = 0.29

# %%
df = pd.read_csv(ENCODED_SPLIT_PATH)

# %%
df['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
predictions = [[row.conceptA, row.conceptB, model.predict(row.conceptA, row.conceptB)]
               for (_, row) in df.iterrows()]

predictions = pd.DataFrame(predictions, columns=['conceptA', 'conceptB', 'isPrerequisite_pred'])

predictions['isPrerequisite'] = df['isPrerequisite']
predictions['dataset'] = df['dataset']
predictions['_split_set'] = df['_split_set']
sorted_predictions = predictions.sort_values(by='isPrerequisite_pred', ascending=False)
sorted_predictions['pred'] = (sorted_predictions['isPrerequisite_pred'] >= THRESHOLD).astype(int)

# %%
sorted_predictions['isPrerequisite'].mean(), df['isPrerequisite'].mean(), sorted_predictions['isPrerequisite_pred'].mean()
# Out:
# (0.2868984820755733, 0.2868984820755733, 0.23067496558838732)

# %%
sorted_predictions['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
df_moocML = sorted_predictions[sorted_predictions['dataset'] == 'moocML']
df_moocDSA = sorted_predictions[sorted_predictions['dataset'] == 'moocDSA']
df_drive = sorted_predictions[sorted_predictions['dataset'] == 'drive']
df_alcpl = sorted_predictions[sorted_predictions['dataset'] == 'al_cpl']

# %%
df_test = sorted_predictions[sorted_predictions['_split_set'] == 'test']

# %%
print(classification_report(df_test['isPrerequisite'], df_test['pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92      2652
#            1       0.88      0.65      0.75      1064
#
#     accuracy                           0.87      3716
#    macro avg       0.88      0.81      0.83      3716
# weighted avg       0.87      0.87      0.87      3716

# %%
print(precision_score(df_test['isPrerequisite'], df_test['pred']), recall_score(df_test['isPrerequisite'], df_test['pred']), f1_score(df_test['isPrerequisite'], df_test['pred']))
# Out:
# 0.879948914431673 0.6475563909774437 0.7460747157552788

# %% [markdown]
# # Generate Pseudo-Labels

# %% [markdown]
# ## NN Model

# %%
def biased_coin_toss(n, p=0.25):
        results = np.random.binomial(1, p, n)
        count_of_ones = np.sum(results)
        return count_of_ones

def generate_pseudo_labels(model, train, device):
    model.eval()  # Set the model to evaluation mode

    users, items, preds = [], [], []
    item = list(train["conceptB"].unique())
    
    for user in tqdm(train["conceptA"].unique()):
        used_items = set(train.loc[train['conceptA'] == user, 'conceptB'])
        user_items = []
        
        for i in item:
            if i in used_items:
                continue
            user_items.append([user, i])
            users.append(user)
            items.append(i)
        
        # Create embeddings for user_items
        user_item_embeddings = []
        for ui in user_items:
            embedding_a = get_embedding(train.loc[train['conceptA'] == ui[0], 'file'].iloc[0], 
                                        train.loc[train['conceptA'] == ui[0], 'conceptA_ind'].iloc[0])
            embedding_b = get_embedding(train.loc[train['conceptB'] == ui[1], 'file'].iloc[0], 
                                        train.loc[train['conceptB'] == ui[1], 'conceptB_ind'].iloc[0])
            combined_features = np.concatenate([embedding_a, embedding_b])
            user_item_embeddings.append(combined_features)

        # Convert to tensor and move to device
        user_item_tensor = torch.tensor(user_item_embeddings, dtype=torch.float32).to(device)

        # Get predictions
        with torch.no_grad():
            batch_preds = model(user_item_tensor).squeeze().cpu().numpy()
        
        preds.extend(list(batch_preds))

    pseudo_predictions = pd.DataFrame(data={"conceptA": users, "conceptB": items, "isPrerequisite_pred": preds})

    pseudo_predictions.sort_values(by=['conceptA', 'isPrerequisite_pred'], ascending=[True, False], inplace=True)
    
    vs = train.groupby('conceptA').agg('sum')['isPrerequisite'].reset_index()

    np.random.seed(SEED)  # Use a fixed seed for reproducibility

    vs['k'] = (vs['isPrerequisite']).apply(biased_coin_toss)
    
    print(f"Original positives: {vs['isPrerequisite'].sum()}, Pseudo positives: {vs['k'].sum()}")

    pseudo_predictions = pseudo_predictions.merge(vs[['conceptA', 'k']], on='conceptA', how='left')    

    pseudo_pos = pseudo_predictions.groupby('conceptA').apply(lambda x : x.head(int(x['k'].values[0]))).reset_index(drop=True)
    pseudo_neg = pseudo_predictions.groupby('conceptA').apply(lambda x : x.tail(int(x['k'].values[0]))).reset_index(drop=True)

    return pseudo_pos, pseudo_neg

def create_new_row(row, train, is_pos):
    # Find the row in train for conceptA
    conceptA_row = train[train['conceptA'] == row['conceptA']].iloc[0]
    
    # Find the row in train for conceptB
    conceptB_row = train[train['conceptB'] == row['conceptB']].iloc[0]
    
    # Create a new row with all columns from conceptA_row
    new_row = conceptA_row.copy()
    
    new_row['conceptA'] = row['conceptA']
    new_row['conceptB'] = row['conceptB']
    new_row['isPrerequisite'] = is_pos
    
    new_row['dataset'] = 'pseudo'
    new_row['file'] = conceptA_row['file']
    new_row['fileB'] = conceptB_row['file']
    
    new_row['conceptA_ind'] = conceptB_row['conceptA_ind']
    new_row['conceptB_ind'] = conceptB_row['conceptB_ind']
    
    return new_row

# %%
train['conceptA'].nunique()
# Out:
# 1384

# %%
train['conceptB'].nunique()
# Out:
# 1600

# %%
# %%time

temp_train = train
# temp_train.drop(columns = ['Unnamed: 0'], inplace=True)
# temp_train['fileB'] = temp_train['file']

# After training your model, generate pseudo-labels
pseudo_pos, pseudo_neg = generate_pseudo_labels(model, temp_train, device)

print("finished pseudo_labeling")

# Create new rows for positive pseudo-labels
new_pos_rows = [create_new_row(row, temp_train, 1) for _, row in pseudo_pos.iterrows()]

# Create new rows for negative pseudo-labels
new_neg_rows = [create_new_row(row, temp_train, 0) for _, row in pseudo_neg.iterrows()]

# Combine original train set with new pseudo-labeled rows
updated_train = pd.concat([temp_train, pd.DataFrame(new_pos_rows + new_neg_rows)], ignore_index=True)

updated_train.sort_values(by=['conceptA']).to_csv(PATH + 'updated_train_set.csv', index=False)

print(f"Original train set shape: {temp_train.shape}")
print(f"Updated train set shape: {updated_train.shape}")

# Now create PyTorch tensors for the neural network
x_train_list = []
y_train_list = []

for _, row in updated_train.iterrows():
    embedding_a = get_embedding(row['file'], row['conceptA_ind'])
    embedding_b = get_embedding(row['fileB'], row['conceptB_ind'])
    combined_features = np.concatenate([embedding_a, embedding_b])
    x_train_list.append(combined_features)
    y_train_list.append(row['isPrerequisite'])

x_train = torch.tensor(x_train_list, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train_list, dtype=torch.long).to(device)

print(f"New x_train shape: {x_train.shape}")
print(f"New y_train shape: {y_train.shape}")
# Out:
#   1%|          | 11/1384 [00:40<1:23:51,  3.66s/it]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# File <timed exec>:6
#
# Cell In[149], line 29, in generate_pseudo_labels(model, train, device)
#      25 for ui in user_items:
#      26     embedding_a = get_embedding(train.loc[train['conceptA'] == ui[0], 'file'].iloc[0],
#      27                                 train.loc[train['conceptA'] == ui[0], 'conceptA_ind'].iloc[0])
#      28     embedding_b = get_embedding(train.loc[train['conceptB'] == ui[1], 'file'].iloc[0],
# ---> 29                                 train.loc[train['conceptB'] == ui[1], 'conceptB_ind'].iloc[0])
#      30     combined_features = np.concatenate([embedding_a, embedding_b])
#      31     user_item_embeddings.append(combined_features)
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\ops\common.py:76, in _unpack_zerodim_and_defer.<locals>.new_method(self, other)
#      72             return NotImplemented
#      74 other = item_from_zerodim(other)
# ---> 76 return method(self, other)
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\arraylike.py:40, in OpsMixin.__eq__(self, other)
#      38 @unpack_zerodim_and_defer("__eq__")
#      39 def __eq__(self, other):
# ---> 40     return self._cmp_method(other, operator.eq)
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\series.py:6110, in Series._cmp_method(self, other, op)
#    6107 lvalues = self._values
#    6108 rvalues = extract_array(other, extract_numpy=True, extract_range=True)
# -> 6110 res_values = ops.comparison_op(lvalues, rvalues, op)
#    6112 return self._construct_result(res_values, name=res_name)
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\ops\array_ops.py:347, in comparison_op(left, right, op)
#     344     res_values = comp_method_OBJECT_ARRAY(op, lvalues, rvalues)
#     346 else:
# --> 347     res_values = _na_arithmetic_op(lvalues, rvalues, op, is_cmp=True)
#     349 return res_values
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\ops\array_ops.py:218, in _na_arithmetic_op(left, right, op, is_cmp)
#     215     func = partial(expressions.evaluate, op)
#     217 try:
# --> 218     result = func(left, right)
#     219 except TypeError:
#     220     if not is_cmp and (
#     221         left.dtype == object or getattr(right, "dtype", None) == object
#     222     ):
#    (...)
#     225         # Don't do this for comparisons, as that will handle complex numbers
#     226         #  incorrectly, see GH#32047
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\computation\expressions.py:242, in evaluate(op, a, b, use_numexpr)
#     239 if op_str is not None:
#     240     if use_numexpr:
#     241         # error: "None" not callable
# --> 242         return _evaluate(op, op_str, a, b)  # type: ignore[misc]
#     243 return _evaluate_standard(op, op_str, a, b)
#
# File ~\Documents\University\bachelor-project-prerequisite-learning\venv\Lib\site-packages\pandas\core\computation\expressions.py:73, in _evaluate_standard(op, op_str, a, b)
#      71 if _TEST_MODE:
#      72     _store_test_result(False)
# ---> 73 return op(a, b)
#
# KeyboardInterrupt:

# %%
train.head()
# Out:
#    conceptA  conceptB  isPrerequisite dataset    file  conceptA_ind  \
# 0         0        10               0  al_cpl  al_cpl           491
# 1         0       656               1  al_cpl  al_cpl           491
# 2         0       928               0  al_cpl  al_cpl           491
# 3         0      1574               1  al_cpl  al_cpl           491
# 4         0       386               1  al_cpl  al_cpl           491
#
#    conceptB_ind   fileB
# 0           427  al_cpl
# 1           438  al_cpl
# 2           451  al_cpl
# 3           483  al_cpl
# 4            76  al_cpl
