# %%
import sys

import numpy as np
import tensorflow as tf
tf.get_logger().setLevel('ERROR') # only show error messages

import pandas as pd

from sklearn.model_selection import train_test_split
from sklearn.metrics import classification_report, precision_score, recall_score, f1_score, accuracy_score

from ncf.ncf import NCF
from ncf.dataset import Dataset as NCFDataset

import torch
import torch.nn as nn
import torch.nn.functional as F

import warnings
warnings.filterwarnings('ignore')

print("System version: {}".format(sys.version))
print("Pandas version: {}".format(pd.__version__))
print("Tensorflow version: {}".format(tf.__version__))
# Out:
# System version: 3.11.2 (tags/v3.11.2:878ead1, Feb  7 2023, 16:38:35) [MSC v.1934 64 bit (AMD64)]
# Pandas version: 2.2.1
# Tensorflow version: 2.16.1

# %%
SEED = 42

PATH = f'C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/generated_data/'
EMBEDDINGS_PATH = 'C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/embeddings'

DATA_PATH =  PATH + 'united_data_embeddings.csv'
ENCODED_PATH = PATH + 'united_data_encoded_embeddings.csv'
ENCODED_SPLIT_PATH = PATH + 'akd_united_split_set'

train_file = PATH + f'akd_train_{SEED}.csv'
test_file = PATH + f'akd_test_{SEED}.csv'

# %% [markdown]
# # Train/Test Split

# %%
df = pd.read_csv(ENCODED_PATH)

df.head()
# Out:
#    Unnamed: 0  conceptA  conceptB  isPrerequisite dataset  file  conceptA_ind  \
# 0           0      1076      1562               1  moocML  mooc           128
# 1           1      1347       855               1  moocML  mooc           160
# 2           2      1347       516               0  moocML  mooc           160
# 3           3      1347      1274               0  moocML  mooc           160
# 4           4      1347       443               0  moocML  mooc           160
#
#    conceptB_ind
# 0           160
# 1           417
# 2           101
# 3           301
# 4           120

# %%
df['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
concepts = list(set(list(df['conceptA']) + list(df['conceptB'])))

# %%
train, test = train_test_split(df, test_size=0.2, random_state=SEED, stratify=df['dataset'])

# %%
df.loc[train.index, '_split_set'] = 'train'
df.loc[test.index, '_split_set'] = 'test'

# %%
df.head()
# Out:
#    Unnamed: 0  conceptA  conceptB  isPrerequisite dataset  file  conceptA_ind  \
# 0           0      1076      1562               1  moocML  mooc           128
# 1           1      1347       855               1  moocML  mooc           160
# 2           2      1347       516               0  moocML  mooc           160
# 3           3      1347      1274               0  moocML  mooc           160
# 4           4      1347       443               0  moocML  mooc           160
#
#    conceptB_ind _split_set
# 0           160      train
# 1           417      train
# 2           101       test
# 3           301      train
# 4           120      train

# %%
train.shape, test.shape
# Out:
# ((14862, 8), (3716, 8))

# %%
train_conceptA = list(set(list(train['conceptA'])))
train_conceptB = list(set(list(train['conceptB'])))
test_conceptA = list(set(list(test['conceptA'])))
test_conceptB = list(set(list(test['conceptB'])))

# %%
train['dataset'].value_counts() / test['dataset'].value_counts()
# Out:
# dataset
# moocML     3.997766
# al_cpl     3.999234
# drive      4.003578
# moocDSA    4.000000
# Name: count, dtype: float64

# %%
a = [x for x in test_conceptA if x not in train_conceptA]
b = [x for x in test_conceptB if x not in train_conceptB]

# %%
maskA = test['conceptA'].isin(a)
maskB = test['conceptB'].isin(b)

# %%
train = pd.concat([train, test[maskA | maskB]], axis=0)
test.drop(index=test[maskA | maskB].index, inplace=True)

# %%
train.shape, test.shape
# Out:
# ((14958, 8), (3620, 8))

# %%
train.sort_values(by=['conceptA']).to_csv(train_file, index=False)
test.sort_values(by=['conceptA']).to_csv(test_file, index=False)

df.to_csv(ENCODED_SPLIT_PATH, index=False)

# %% [markdown]
# # Generate Train Set For Tensor

# %%
# Load the train, test set
train = pd.read_csv(train_file)
test = pd.read_csv(test_file)

# Load the embedding dataframes
embedding_dfs = {
    'al_cpl': pd.read_csv(EMBEDDINGS_PATH + r'\al_cpl_embeddings_mistral.csv'),
    'drive': pd.read_csv(EMBEDDINGS_PATH + r'\drive_embeddings_mistral.csv'),
    'mooc': pd.read_csv(EMBEDDINGS_PATH + r'\mooc_embeddings_mistral.csv')
}

# Function to get embedding for a concept
def get_embedding(file, concept_ind):
    embedding = embedding_dfs[file].loc[concept_ind].iloc[1:].values
    return embedding

# Function to process a dataset
def process_dataset(df):
    x_list = []
    y_list = []

    for _, row in df.iterrows():
        file = row['file']
        
        # Get embeddings for conceptA and conceptB
        embedding_a = get_embedding(file, row['conceptA_ind'])
        embedding_b = get_embedding(file, row['conceptB_ind'])
        
        # Combine the embeddings
        combined_features = np.concatenate([embedding_a, embedding_b])
        
        x_list.append(combined_features)
        y_list.append(row['isPrerequisite'])

    return x_list, y_list

# Process train and test sets
x_train_list, y_train_list = process_dataset(train)
x_test_list, y_test_list = process_dataset(test)

# Convert to PyTorch tensors
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')

x_train = torch.tensor(x_train_list, dtype=torch.float32).to(device)
y_train = torch.tensor(y_train_list, dtype=torch.long).to(device)

x_test = torch.tensor(x_test_list, dtype=torch.float32).to(device)
y_test = torch.tensor(y_test_list, dtype=torch.long).to(device)

print(f"x_train shape: {x_train.shape}")
print(f"y_train shape: {y_train.shape}")
print(f"x_test shape: {x_test.shape}")
print(f"y_test shape: {y_test.shape}")
# Out:
# x_train shape: torch.Size([14958, 2048])
# y_train shape: torch.Size([14958])
# x_test shape: torch.Size([3620, 2048])
# y_test shape: torch.Size([3620])

# %% [markdown]
# # Content-Based Learning

# %%
class BinaryClassifier(nn.Module):
    def __init__(self, input_size):
        super(BinaryClassifier, self).__init__()
        self.fc1 = nn.Linear(input_size, 512)  # Fully connected layer 1
        self.dropout1 = nn.Dropout(0.8)         # Dropout layer with 20% probability
        self.fc2 = nn.Linear(512, 256)          # Fully connected layer 2
        self.dropout2 = nn.Dropout(0.8)         # Dropout layer with 20% probability
        self.fc3 = nn.Linear(256, 1)            # Output layer
        
    def forward(self, x):
        x = F.relu(self.fc1(x))       # Apply ReLU activation to the first fully connected layer
        x = self.dropout1(x)          # Apply dropout to the output of the first layer
        x = F.relu(self.fc2(x))       # Apply ReLU activation to the second fully connected layer
        x = self.dropout2(x)          # Apply dropout to the output of the second layer
        x = torch.sigmoid(self.fc3(x))  # Apply sigmoid activation to the output layer for binary classification
        return x

# %%
# Assuming x_train is your input tensor
input_size = x_train.shape[1]  # This should be 2048 (1024 * 2) based on your previous code

# Initialize the model
model = BinaryClassifier(input_size)

# Move the model to the same device as your data
model = model.to(device)

# Define loss function and optimizer
criterion = nn.BCELoss()  # Binary Cross Entropy Loss
optimizer = torch.optim.Adam(model.parameters(), lr=0.001)

# Training loop (simplified)
num_epochs = 500
for epoch in range(num_epochs):
    model.train()
    outputs = model(x_train)
    loss = criterion(outputs, y_train.float().unsqueeze(1))
    
    optimizer.zero_grad()
    loss.backward()
    optimizer.step()
    
    with torch.no_grad():
        model.eval()  # Set the model to evaluation mode
        train_preds = (outputs >= 0.5).float()  # Convert probabilities to binary predictions
        train_acc = accuracy_score(y_train.cpu().numpy(), train_preds.cpu().numpy())
        train_f1 = f1_score(y_train.cpu().numpy(), train_preds.cpu().numpy())

    with torch.no_grad():
        test_outputs = model(x_test)
        test_preds = (test_outputs >= 0.5).float()  # Convert probabilities to binary predictions
        test_acc = accuracy_score(y_test.cpu().numpy(), test_preds.cpu().numpy())
        test_f1 = f1_score(y_test.cpu().numpy(), test_preds.cpu().numpy())

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}, Train Accuracy: {train_acc:.4f}, Train F1: {train_f1:.4f}, Test Accuracy: {test_acc:.4f}, Test F1: {test_f1:.4f}')

    print(f'Epoch [{epoch+1}/{num_epochs}], Loss: {loss.item():.4f}')
# Out:
# Epoch [1/500], Loss: 0.6952, Train Accuracy: 0.4372, Train F1: 0.3894, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [1/500], Loss: 0.6952
# Epoch [2/500], Loss: 0.6740, Train Accuracy: 0.7055, Train F1: 0.0226, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [2/500], Loss: 0.6740
# Epoch [3/500], Loss: 0.6488, Train Accuracy: 0.7122, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [3/500], Loss: 0.6488
# Epoch [4/500], Loss: 0.6223, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [4/500], Loss: 0.6223
# Epoch [5/500], Loss: 0.6087, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [5/500], Loss: 0.6087
# Epoch [6/500], Loss: 0.6093, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [6/500], Loss: 0.6093
# Epoch [7/500], Loss: 0.6256, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [7/500], Loss: 0.6256
# Epoch [8/500], Loss: 0.6224, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [8/500], Loss: 0.6224
# Epoch [9/500], Loss: 0.6093, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [9/500], Loss: 0.6093
# Epoch [10/500], Loss: 0.6020, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [10/500], Loss: 0.6020
# Epoch [11/500], Loss: 0.5999, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [11/500], Loss: 0.5999
# Epoch [12/500], Loss: 0.6025, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [12/500], Loss: 0.6025
# Epoch [13/500], Loss: 0.6047, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [13/500], Loss: 0.6047
# Epoch [14/500], Loss: 0.6056, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [14/500], Loss: 0.6056
# Epoch [15/500], Loss: 0.6042, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [15/500], Loss: 0.6042
# Epoch [16/500], Loss: 0.6012, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [16/500], Loss: 0.6012
# Epoch [17/500], Loss: 0.5987, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [17/500], Loss: 0.5987
# Epoch [18/500], Loss: 0.5972, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [18/500], Loss: 0.5972
# Epoch [19/500], Loss: 0.5933, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [19/500], Loss: 0.5933
# Epoch [20/500], Loss: 0.5919, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [20/500], Loss: 0.5919
# Epoch [21/500], Loss: 0.5937, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [21/500], Loss: 0.5937
# Epoch [22/500], Loss: 0.5923, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [22/500], Loss: 0.5923
# Epoch [23/500], Loss: 0.5919, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [23/500], Loss: 0.5919
# Epoch [24/500], Loss: 0.5894, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [24/500], Loss: 0.5894
# Epoch [25/500], Loss: 0.5864, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [25/500], Loss: 0.5864
# Epoch [26/500], Loss: 0.5859, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [26/500], Loss: 0.5859
# Epoch [27/500], Loss: 0.5821, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [27/500], Loss: 0.5821
# Epoch [28/500], Loss: 0.5831, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [28/500], Loss: 0.5831
# Epoch [29/500], Loss: 0.5781, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [29/500], Loss: 0.5781
# Epoch [30/500], Loss: 0.5787, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [30/500], Loss: 0.5787
# Epoch [31/500], Loss: 0.5750, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [31/500], Loss: 0.5750
# Epoch [32/500], Loss: 0.5739, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [32/500], Loss: 0.5739
# Epoch [33/500], Loss: 0.5705, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [33/500], Loss: 0.5705
# Epoch [34/500], Loss: 0.5681, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [34/500], Loss: 0.5681
# Epoch [35/500], Loss: 0.5662, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [35/500], Loss: 0.5662
# Epoch [36/500], Loss: 0.5611, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [36/500], Loss: 0.5611
# Epoch [37/500], Loss: 0.5601, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [37/500], Loss: 0.5601
# Epoch [38/500], Loss: 0.5535, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [38/500], Loss: 0.5535
# Epoch [39/500], Loss: 0.5515, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [39/500], Loss: 0.5515
# Epoch [40/500], Loss: 0.5477, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [40/500], Loss: 0.5477
# Epoch [41/500], Loss: 0.5432, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [41/500], Loss: 0.5432
# Epoch [42/500], Loss: 0.5366, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [42/500], Loss: 0.5366
# Epoch [43/500], Loss: 0.5339, Train Accuracy: 0.7127, Train F1: 0.0005, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [43/500], Loss: 0.5339
# Epoch [44/500], Loss: 0.5309, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [44/500], Loss: 0.5309
# Epoch [45/500], Loss: 0.5266, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [45/500], Loss: 0.5266
# Epoch [46/500], Loss: 0.5217, Train Accuracy: 0.7125, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [46/500], Loss: 0.5217
# Epoch [47/500], Loss: 0.5199, Train Accuracy: 0.7127, Train F1: 0.0009, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [47/500], Loss: 0.5199
# Epoch [48/500], Loss: 0.5145, Train Accuracy: 0.7127, Train F1: 0.0009, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [48/500], Loss: 0.5145
# Epoch [49/500], Loss: 0.5108, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [49/500], Loss: 0.5108
# Epoch [50/500], Loss: 0.5076, Train Accuracy: 0.7126, Train F1: 0.0000, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [50/500], Loss: 0.5076
# Epoch [51/500], Loss: 0.5047, Train Accuracy: 0.7127, Train F1: 0.0009, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [51/500], Loss: 0.5047
# Epoch [52/500], Loss: 0.5010, Train Accuracy: 0.7129, Train F1: 0.0023, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [52/500], Loss: 0.5010
# Epoch [53/500], Loss: 0.4962, Train Accuracy: 0.7128, Train F1: 0.0019, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [53/500], Loss: 0.4962
# Epoch [54/500], Loss: 0.4925, Train Accuracy: 0.7132, Train F1: 0.0051, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [54/500], Loss: 0.4925
# Epoch [55/500], Loss: 0.4896, Train Accuracy: 0.7133, Train F1: 0.0056, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [55/500], Loss: 0.4896
# Epoch [56/500], Loss: 0.4843, Train Accuracy: 0.7133, Train F1: 0.0060, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [56/500], Loss: 0.4843
# Epoch [57/500], Loss: 0.4829, Train Accuracy: 0.7137, Train F1: 0.0106, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [57/500], Loss: 0.4829
# Epoch [58/500], Loss: 0.4786, Train Accuracy: 0.7147, Train F1: 0.0184, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [58/500], Loss: 0.4786
# Epoch [59/500], Loss: 0.4761, Train Accuracy: 0.7151, Train F1: 0.0220, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [59/500], Loss: 0.4761
# Epoch [60/500], Loss: 0.4724, Train Accuracy: 0.7171, Train F1: 0.0364, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [60/500], Loss: 0.4724
# Epoch [61/500], Loss: 0.4680, Train Accuracy: 0.7196, Train F1: 0.0584, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [61/500], Loss: 0.4680
# Epoch [62/500], Loss: 0.4667, Train Accuracy: 0.7199, Train F1: 0.0643, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [62/500], Loss: 0.4667
# Epoch [63/500], Loss: 0.4621, Train Accuracy: 0.7224, Train F1: 0.0830, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [63/500], Loss: 0.4621
# Epoch [64/500], Loss: 0.4601, Train Accuracy: 0.7286, Train F1: 0.1303, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [64/500], Loss: 0.4601
# Epoch [65/500], Loss: 0.4581, Train Accuracy: 0.7351, Train F1: 0.1773, Test Accuracy: 0.7152, Test F1: 0.0000
# Epoch [65/500], Loss: 0.4581
# Epoch [66/500], Loss: 0.4540, Train Accuracy: 0.7402, Train F1: 0.2089, Test Accuracy: 0.7340, Test F1: 0.1485
# Epoch [66/500], Loss: 0.4540
# Epoch [67/500], Loss: 0.4536, Train Accuracy: 0.7449, Train F1: 0.2438, Test Accuracy: 0.7718, Test F1: 0.3827
# Epoch [67/500], Loss: 0.4536
# Epoch [68/500], Loss: 0.4496, Train Accuracy: 0.7580, Train F1: 0.3236, Test Accuracy: 0.7856, Test F1: 0.4535
# Epoch [68/500], Loss: 0.4496
# Epoch [69/500], Loss: 0.4472, Train Accuracy: 0.7692, Train F1: 0.3788, Test Accuracy: 0.7854, Test F1: 0.4517
# Epoch [69/500], Loss: 0.4472
# Epoch [70/500], Loss: 0.4431, Train Accuracy: 0.7724, Train F1: 0.4013, Test Accuracy: 0.7975, Test F1: 0.5084
# Epoch [70/500], Loss: 0.4431
# Epoch [71/500], Loss: 0.4407, Train Accuracy: 0.7808, Train F1: 0.4473, Test Accuracy: 0.8055, Test F1: 0.5458
# Epoch [71/500], Loss: 0.4407
# Epoch [72/500], Loss: 0.4405, Train Accuracy: 0.7934, Train F1: 0.5045, Test Accuracy: 0.8050, Test F1: 0.5433
# Epoch [72/500], Loss: 0.4405
# Epoch [73/500], Loss: 0.4374, Train Accuracy: 0.7938, Train F1: 0.5119, Test Accuracy: 0.8061, Test F1: 0.5488
# Epoch [73/500], Loss: 0.4374
# Epoch [74/500], Loss: 0.4346, Train Accuracy: 0.8000, Train F1: 0.5334, Test Accuracy: 0.8127, Test F1: 0.5794
# Epoch [74/500], Loss: 0.4346
# Epoch [75/500], Loss: 0.4324, Train Accuracy: 0.8069, Train F1: 0.5673, Test Accuracy: 0.8113, Test F1: 0.5734
# Epoch [75/500], Loss: 0.4324
# Epoch [76/500], Loss: 0.4301, Train Accuracy: 0.8092, Train F1: 0.5736, Test Accuracy: 0.8124, Test F1: 0.5780
# Epoch [76/500], Loss: 0.4301
# Epoch [77/500], Loss: 0.4277, Train Accuracy: 0.8093, Train F1: 0.5742, Test Accuracy: 0.8160, Test F1: 0.5944
# Epoch [77/500], Loss: 0.4277
# Epoch [78/500], Loss: 0.4261, Train Accuracy: 0.8171, Train F1: 0.6038, Test Accuracy: 0.8169, Test F1: 0.6013
# Epoch [78/500], Loss: 0.4261
# Epoch [79/500], Loss: 0.4237, Train Accuracy: 0.8174, Train F1: 0.6092, Test Accuracy: 0.8169, Test F1: 0.5989
# Epoch [79/500], Loss: 0.4237
# Epoch [80/500], Loss: 0.4229, Train Accuracy: 0.8175, Train F1: 0.6090, Test Accuracy: 0.8188, Test F1: 0.6137
# Epoch [80/500], Loss: 0.4229
# Epoch [81/500], Loss: 0.4201, Train Accuracy: 0.8228, Train F1: 0.6293, Test Accuracy: 0.8210, Test F1: 0.6219
# Epoch [81/500], Loss: 0.4201
# Epoch [82/500], Loss: 0.4168, Train Accuracy: 0.8239, Train F1: 0.6367, Test Accuracy: 0.8199, Test F1: 0.6082
# Epoch [82/500], Loss: 0.4168
# Epoch [83/500], Loss: 0.4175, Train Accuracy: 0.8206, Train F1: 0.6188, Test Accuracy: 0.8268, Test F1: 0.6468
# Epoch [83/500], Loss: 0.4175
# Epoch [84/500], Loss: 0.4128, Train Accuracy: 0.8295, Train F1: 0.6578, Test Accuracy: 0.8249, Test F1: 0.6318
# Epoch [84/500], Loss: 0.4128
# Epoch [85/500], Loss: 0.4120, Train Accuracy: 0.8250, Train F1: 0.6395, Test Accuracy: 0.8268, Test F1: 0.6353
# Epoch [85/500], Loss: 0.4120
# Epoch [86/500], Loss: 0.4087, Train Accuracy: 0.8257, Train F1: 0.6409, Test Accuracy: 0.8271, Test F1: 0.6553
# Epoch [86/500], Loss: 0.4087
# Epoch [87/500], Loss: 0.4093, Train Accuracy: 0.8322, Train F1: 0.6716, Test Accuracy: 0.8262, Test F1: 0.6375
# Epoch [87/500], Loss: 0.4093
# Epoch [88/500], Loss: 0.4073, Train Accuracy: 0.8279, Train F1: 0.6467, Test Accuracy: 0.8273, Test F1: 0.6471
# Epoch [88/500], Loss: 0.4073
# Epoch [89/500], Loss: 0.4038, Train Accuracy: 0.8326, Train F1: 0.6652, Test Accuracy: 0.8290, Test F1: 0.6597
# Epoch [89/500], Loss: 0.4038
# Epoch [90/500], Loss: 0.4021, Train Accuracy: 0.8344, Train F1: 0.6774, Test Accuracy: 0.8287, Test F1: 0.6412
# Epoch [90/500], Loss: 0.4021
# Epoch [91/500], Loss: 0.4015, Train Accuracy: 0.8312, Train F1: 0.6557, Test Accuracy: 0.8293, Test F1: 0.6597
# Epoch [91/500], Loss: 0.4015
# Epoch [92/500], Loss: 0.3988, Train Accuracy: 0.8383, Train F1: 0.6864, Test Accuracy: 0.8290, Test F1: 0.6601
# Epoch [92/500], Loss: 0.3988
# Epoch [93/500], Loss: 0.3963, Train Accuracy: 0.8386, Train F1: 0.6867, Test Accuracy: 0.8304, Test F1: 0.6543
# Epoch [93/500], Loss: 0.3963
# Epoch [94/500], Loss: 0.3966, Train Accuracy: 0.8358, Train F1: 0.6739, Test Accuracy: 0.8312, Test F1: 0.6720
# Epoch [94/500], Loss: 0.3966
# Epoch [95/500], Loss: 0.3944, Train Accuracy: 0.8418, Train F1: 0.6997, Test Accuracy: 0.8296, Test F1: 0.6589
# Epoch [95/500], Loss: 0.3944
# Epoch [96/500], Loss: 0.3915, Train Accuracy: 0.8389, Train F1: 0.6855, Test Accuracy: 0.8304, Test F1: 0.6630
# Epoch [96/500], Loss: 0.3915
# Epoch [97/500], Loss: 0.3894, Train Accuracy: 0.8400, Train F1: 0.6906, Test Accuracy: 0.8331, Test F1: 0.6777
# Epoch [97/500], Loss: 0.3894
# Epoch [98/500], Loss: 0.3873, Train Accuracy: 0.8434, Train F1: 0.7049, Test Accuracy: 0.8329, Test F1: 0.6652
# Epoch [98/500], Loss: 0.3873
# Epoch [99/500], Loss: 0.3845, Train Accuracy: 0.8427, Train F1: 0.6943, Test Accuracy: 0.8340, Test F1: 0.6812
# Epoch [99/500], Loss: 0.3845
# Epoch [100/500], Loss: 0.3833, Train Accuracy: 0.8456, Train F1: 0.7107, Test Accuracy: 0.8331, Test F1: 0.6721
# Epoch [100/500], Loss: 0.3833
# Epoch [101/500], Loss: 0.3824, Train Accuracy: 0.8435, Train F1: 0.7011, Test Accuracy: 0.8348, Test F1: 0.6795
# Epoch [101/500], Loss: 0.3824
# Epoch [102/500], Loss: 0.3800, Train Accuracy: 0.8465, Train F1: 0.7099, Test Accuracy: 0.8362, Test F1: 0.6847
# Epoch [102/500], Loss: 0.3800
# Epoch [103/500], Loss: 0.3767, Train Accuracy: 0.8476, Train F1: 0.7129, Test Accuracy: 0.8362, Test F1: 0.6779
# Epoch [103/500], Loss: 0.3767
# Epoch [104/500], Loss: 0.3771, Train Accuracy: 0.8460, Train F1: 0.7057, Test Accuracy: 0.8378, Test F1: 0.6947
# Epoch [104/500], Loss: 0.3771
# Epoch [105/500], Loss: 0.3727, Train Accuracy: 0.8519, Train F1: 0.7277, Test Accuracy: 0.8384, Test F1: 0.6763
# Epoch [105/500], Loss: 0.3727
# Epoch [106/500], Loss: 0.3737, Train Accuracy: 0.8490, Train F1: 0.7080, Test Accuracy: 0.8412, Test F1: 0.7047
# Epoch [106/500], Loss: 0.3737
# Epoch [107/500], Loss: 0.3725, Train Accuracy: 0.8537, Train F1: 0.7357, Test Accuracy: 0.8387, Test F1: 0.6826
# Epoch [107/500], Loss: 0.3725
# Epoch [108/500], Loss: 0.3694, Train Accuracy: 0.8508, Train F1: 0.7157, Test Accuracy: 0.8409, Test F1: 0.6933
# Epoch [108/500], Loss: 0.3694
# Epoch [109/500], Loss: 0.3652, Train Accuracy: 0.8531, Train F1: 0.7250, Test Accuracy: 0.8425, Test F1: 0.7025
# Epoch [109/500], Loss: 0.3652
# Epoch [110/500], Loss: 0.3657, Train Accuracy: 0.8553, Train F1: 0.7342, Test Accuracy: 0.8436, Test F1: 0.6964
# Epoch [110/500], Loss: 0.3657
# Epoch [111/500], Loss: 0.3657, Train Accuracy: 0.8510, Train F1: 0.7200, Test Accuracy: 0.8431, Test F1: 0.7072
# Epoch [111/500], Loss: 0.3657
# Epoch [112/500], Loss: 0.3603, Train Accuracy: 0.8571, Train F1: 0.7423, Test Accuracy: 0.8450, Test F1: 0.6969
# Epoch [112/500], Loss: 0.3603
# Epoch [113/500], Loss: 0.3588, Train Accuracy: 0.8560, Train F1: 0.7263, Test Accuracy: 0.8445, Test F1: 0.7102
# Epoch [113/500], Loss: 0.3588
# Epoch [114/500], Loss: 0.3557, Train Accuracy: 0.8584, Train F1: 0.7440, Test Accuracy: 0.8467, Test F1: 0.7056
# Epoch [114/500], Loss: 0.3557
# Epoch [115/500], Loss: 0.3565, Train Accuracy: 0.8584, Train F1: 0.7383, Test Accuracy: 0.8489, Test F1: 0.7173
# Epoch [115/500], Loss: 0.3565
# Epoch [116/500], Loss: 0.3547, Train Accuracy: 0.8600, Train F1: 0.7444, Test Accuracy: 0.8464, Test F1: 0.7155
# Epoch [116/500], Loss: 0.3547
# Epoch [117/500], Loss: 0.3525, Train Accuracy: 0.8621, Train F1: 0.7531, Test Accuracy: 0.8467, Test F1: 0.7011
# Epoch [117/500], Loss: 0.3525
# Epoch [118/500], Loss: 0.3522, Train Accuracy: 0.8566, Train F1: 0.7298, Test Accuracy: 0.8431, Test F1: 0.7157
# Epoch [118/500], Loss: 0.3522
# Epoch [119/500], Loss: 0.3506, Train Accuracy: 0.8616, Train F1: 0.7576, Test Accuracy: 0.8478, Test F1: 0.7039
# Epoch [119/500], Loss: 0.3506
# Epoch [120/500], Loss: 0.3503, Train Accuracy: 0.8595, Train F1: 0.7348, Test Accuracy: 0.8478, Test F1: 0.7199
# Epoch [120/500], Loss: 0.3503
# Epoch [121/500], Loss: 0.3453, Train Accuracy: 0.8644, Train F1: 0.7592, Test Accuracy: 0.8514, Test F1: 0.7204
# Epoch [121/500], Loss: 0.3453
# Epoch [122/500], Loss: 0.3427, Train Accuracy: 0.8641, Train F1: 0.7525, Test Accuracy: 0.8528, Test F1: 0.7211
# Epoch [122/500], Loss: 0.3427
# Epoch [123/500], Loss: 0.3412, Train Accuracy: 0.8638, Train F1: 0.7506, Test Accuracy: 0.8445, Test F1: 0.7172
# Epoch [123/500], Loss: 0.3412
# Epoch [124/500], Loss: 0.3395, Train Accuracy: 0.8679, Train F1: 0.7682, Test Accuracy: 0.8514, Test F1: 0.7153
# Epoch [124/500], Loss: 0.3395
# Epoch [125/500], Loss: 0.3385, Train Accuracy: 0.8652, Train F1: 0.7514, Test Accuracy: 0.8500, Test F1: 0.7237
# Epoch [125/500], Loss: 0.3385
# Epoch [126/500], Loss: 0.3366, Train Accuracy: 0.8672, Train F1: 0.7635, Test Accuracy: 0.8519, Test F1: 0.7263
# Epoch [126/500], Loss: 0.3366
# Epoch [127/500], Loss: 0.3370, Train Accuracy: 0.8688, Train F1: 0.7646, Test Accuracy: 0.8525, Test F1: 0.7198
# Epoch [127/500], Loss: 0.3370
# Epoch [128/500], Loss: 0.3362, Train Accuracy: 0.8676, Train F1: 0.7588, Test Accuracy: 0.8456, Test F1: 0.7234
# Epoch [128/500], Loss: 0.3362
# Epoch [129/500], Loss: 0.3323, Train Accuracy: 0.8698, Train F1: 0.7742, Test Accuracy: 0.8522, Test F1: 0.7180
# Epoch [129/500], Loss: 0.3323
# Epoch [130/500], Loss: 0.3312, Train Accuracy: 0.8677, Train F1: 0.7553, Test Accuracy: 0.8494, Test F1: 0.7271
# Epoch [130/500], Loss: 0.3312
# Epoch [131/500], Loss: 0.3289, Train Accuracy: 0.8718, Train F1: 0.7760, Test Accuracy: 0.8525, Test F1: 0.7273
# Epoch [131/500], Loss: 0.3289
# Epoch [132/500], Loss: 0.3267, Train Accuracy: 0.8709, Train F1: 0.7699, Test Accuracy: 0.8541, Test F1: 0.7276
# Epoch [132/500], Loss: 0.3267
# Epoch [133/500], Loss: 0.3240, Train Accuracy: 0.8726, Train F1: 0.7694, Test Accuracy: 0.8494, Test F1: 0.7287
# Epoch [133/500], Loss: 0.3240
# Epoch [134/500], Loss: 0.3205, Train Accuracy: 0.8737, Train F1: 0.7792, Test Accuracy: 0.8561, Test F1: 0.7299
# Epoch [134/500], Loss: 0.3205
# Epoch [135/500], Loss: 0.3192, Train Accuracy: 0.8738, Train F1: 0.7704, Test Accuracy: 0.8528, Test F1: 0.7323
# Epoch [135/500], Loss: 0.3192
# Epoch [136/500], Loss: 0.3196, Train Accuracy: 0.8769, Train F1: 0.7830, Test Accuracy: 0.8539, Test F1: 0.7324
# Epoch [136/500], Loss: 0.3196
# Epoch [137/500], Loss: 0.3178, Train Accuracy: 0.8753, Train F1: 0.7786, Test Accuracy: 0.8544, Test F1: 0.7296
# Epoch [137/500], Loss: 0.3178
# Epoch [138/500], Loss: 0.3165, Train Accuracy: 0.8739, Train F1: 0.7738, Test Accuracy: 0.8506, Test F1: 0.7318
# Epoch [138/500], Loss: 0.3165
# Epoch [139/500], Loss: 0.3154, Train Accuracy: 0.8761, Train F1: 0.7853, Test Accuracy: 0.8564, Test F1: 0.7289
# Epoch [139/500], Loss: 0.3154
# Epoch [140/500], Loss: 0.3155, Train Accuracy: 0.8777, Train F1: 0.7758, Test Accuracy: 0.8486, Test F1: 0.7314
# Epoch [140/500], Loss: 0.3155
# Epoch [141/500], Loss: 0.3132, Train Accuracy: 0.8775, Train F1: 0.7901, Test Accuracy: 0.8575, Test F1: 0.7335
# Epoch [141/500], Loss: 0.3132
# Epoch [142/500], Loss: 0.3108, Train Accuracy: 0.8790, Train F1: 0.7811, Test Accuracy: 0.8530, Test F1: 0.7310
# Epoch [142/500], Loss: 0.3108
# Epoch [143/500], Loss: 0.3065, Train Accuracy: 0.8810, Train F1: 0.7890, Test Accuracy: 0.8522, Test F1: 0.7348
# Epoch [143/500], Loss: 0.3065
# Epoch [144/500], Loss: 0.3039, Train Accuracy: 0.8834, Train F1: 0.7982, Test Accuracy: 0.8591, Test F1: 0.7333
# Epoch [144/500], Loss: 0.3039
# Epoch [145/500], Loss: 0.3058, Train Accuracy: 0.8780, Train F1: 0.7779, Test Accuracy: 0.8544, Test F1: 0.7443
# Epoch [145/500], Loss: 0.3058
# Epoch [146/500], Loss: 0.3052, Train Accuracy: 0.8802, Train F1: 0.7961, Test Accuracy: 0.8599, Test F1: 0.7377
# Epoch [146/500], Loss: 0.3052
# Epoch [147/500], Loss: 0.3052, Train Accuracy: 0.8797, Train F1: 0.7834, Test Accuracy: 0.8550, Test F1: 0.7397
# Epoch [147/500], Loss: 0.3052
# Epoch [148/500], Loss: 0.2997, Train Accuracy: 0.8853, Train F1: 0.8009, Test Accuracy: 0.8564, Test F1: 0.7405
# Epoch [148/500], Loss: 0.2997
# Epoch [149/500], Loss: 0.2983, Train Accuracy: 0.8837, Train F1: 0.7973, Test Accuracy: 0.8608, Test F1: 0.7394
# Epoch [149/500], Loss: 0.2983
# Epoch [150/500], Loss: 0.2967, Train Accuracy: 0.8843, Train F1: 0.7912, Test Accuracy: 0.8558, Test F1: 0.7436
# Epoch [150/500], Loss: 0.2967
# Epoch [151/500], Loss: 0.2978, Train Accuracy: 0.8842, Train F1: 0.8017, Test Accuracy: 0.8635, Test F1: 0.7461
# Epoch [151/500], Loss: 0.2978
# Epoch [152/500], Loss: 0.2946, Train Accuracy: 0.8859, Train F1: 0.7957, Test Accuracy: 0.8572, Test F1: 0.7437
# Epoch [152/500], Loss: 0.2946
# Epoch [153/500], Loss: 0.2929, Train Accuracy: 0.8854, Train F1: 0.8009, Test Accuracy: 0.8586, Test F1: 0.7432
# Epoch [153/500], Loss: 0.2929
# Epoch [154/500], Loss: 0.2899, Train Accuracy: 0.8881, Train F1: 0.8039, Test Accuracy: 0.8591, Test F1: 0.7414
# Epoch [154/500], Loss: 0.2899
# Epoch [155/500], Loss: 0.2880, Train Accuracy: 0.8880, Train F1: 0.8026, Test Accuracy: 0.8588, Test F1: 0.7467
# Epoch [155/500], Loss: 0.2880
# Epoch [156/500], Loss: 0.2887, Train Accuracy: 0.8882, Train F1: 0.8063, Test Accuracy: 0.8602, Test F1: 0.7442
# Epoch [156/500], Loss: 0.2887
# Epoch [157/500], Loss: 0.2858, Train Accuracy: 0.8872, Train F1: 0.8005, Test Accuracy: 0.8597, Test F1: 0.7478
# Epoch [157/500], Loss: 0.2858
# Epoch [158/500], Loss: 0.2852, Train Accuracy: 0.8904, Train F1: 0.8094, Test Accuracy: 0.8619, Test F1: 0.7480
# Epoch [158/500], Loss: 0.2852
# Epoch [159/500], Loss: 0.2827, Train Accuracy: 0.8902, Train F1: 0.8062, Test Accuracy: 0.8594, Test F1: 0.7469
# Epoch [159/500], Loss: 0.2827
# Epoch [160/500], Loss: 0.2837, Train Accuracy: 0.8902, Train F1: 0.8092, Test Accuracy: 0.8616, Test F1: 0.7458
# Epoch [160/500], Loss: 0.2837
# Epoch [161/500], Loss: 0.2816, Train Accuracy: 0.8885, Train F1: 0.8025, Test Accuracy: 0.8605, Test F1: 0.7484
# Epoch [161/500], Loss: 0.2816
# Epoch [162/500], Loss: 0.2807, Train Accuracy: 0.8922, Train F1: 0.8132, Test Accuracy: 0.8624, Test F1: 0.7485
# Epoch [162/500], Loss: 0.2807
# Epoch [163/500], Loss: 0.2757, Train Accuracy: 0.8898, Train F1: 0.8072, Test Accuracy: 0.8627, Test F1: 0.7514
# Epoch [163/500], Loss: 0.2757
# Epoch [164/500], Loss: 0.2757, Train Accuracy: 0.8915, Train F1: 0.8107, Test Accuracy: 0.8613, Test F1: 0.7490
# Epoch [164/500], Loss: 0.2757
# Epoch [165/500], Loss: 0.2736, Train Accuracy: 0.8930, Train F1: 0.8130, Test Accuracy: 0.8638, Test F1: 0.7519
# Epoch [165/500], Loss: 0.2736
# Epoch [166/500], Loss: 0.2730, Train Accuracy: 0.8924, Train F1: 0.8114, Test Accuracy: 0.8627, Test F1: 0.7529
# Epoch [166/500], Loss: 0.2730
# Epoch [167/500], Loss: 0.2716, Train Accuracy: 0.8936, Train F1: 0.8144, Test Accuracy: 0.8627, Test F1: 0.7526
# Epoch [167/500], Loss: 0.2716
# Epoch [168/500], Loss: 0.2706, Train Accuracy: 0.8920, Train F1: 0.8126, Test Accuracy: 0.8655, Test F1: 0.7527
# Epoch [168/500], Loss: 0.2706
# Epoch [169/500], Loss: 0.2693, Train Accuracy: 0.8968, Train F1: 0.8165, Test Accuracy: 0.8630, Test F1: 0.7602
# Epoch [169/500], Loss: 0.2693
# Epoch [170/500], Loss: 0.2689, Train Accuracy: 0.8941, Train F1: 0.8223, Test Accuracy: 0.8671, Test F1: 0.7421
# Epoch [170/500], Loss: 0.2689
# Epoch [171/500], Loss: 0.2769, Train Accuracy: 0.8889, Train F1: 0.7933, Test Accuracy: 0.8624, Test F1: 0.7688
# Epoch [171/500], Loss: 0.2769
# Epoch [172/500], Loss: 0.2731, Train Accuracy: 0.8918, Train F1: 0.8232, Test Accuracy: 0.8693, Test F1: 0.7517
# Epoch [172/500], Loss: 0.2731
# Epoch [173/500], Loss: 0.2684, Train Accuracy: 0.8938, Train F1: 0.8069, Test Accuracy: 0.8660, Test F1: 0.7564
# Epoch [173/500], Loss: 0.2684
# Epoch [174/500], Loss: 0.2628, Train Accuracy: 0.8986, Train F1: 0.8232, Test Accuracy: 0.8666, Test F1: 0.7661
# Epoch [174/500], Loss: 0.2628
# Epoch [175/500], Loss: 0.2633, Train Accuracy: 0.8967, Train F1: 0.8258, Test Accuracy: 0.8688, Test F1: 0.7507
# Epoch [175/500], Loss: 0.2633
# Epoch [176/500], Loss: 0.2657, Train Accuracy: 0.8939, Train F1: 0.8084, Test Accuracy: 0.8671, Test F1: 0.7675
# Epoch [176/500], Loss: 0.2657
# Epoch [177/500], Loss: 0.2599, Train Accuracy: 0.8984, Train F1: 0.8293, Test Accuracy: 0.8674, Test F1: 0.7573
# Epoch [177/500], Loss: 0.2599
# Epoch [178/500], Loss: 0.2583, Train Accuracy: 0.8993, Train F1: 0.8234, Test Accuracy: 0.8674, Test F1: 0.7563
# Epoch [178/500], Loss: 0.2583
# Epoch [179/500], Loss: 0.2554, Train Accuracy: 0.9029, Train F1: 0.8282, Test Accuracy: 0.8660, Test F1: 0.7660
# Epoch [179/500], Loss: 0.2554
# Epoch [180/500], Loss: 0.2543, Train Accuracy: 0.9019, Train F1: 0.8349, Test Accuracy: 0.8691, Test F1: 0.7557
# Epoch [180/500], Loss: 0.2543
# Epoch [181/500], Loss: 0.2551, Train Accuracy: 0.8995, Train F1: 0.8201, Test Accuracy: 0.8674, Test F1: 0.7635
# Epoch [181/500], Loss: 0.2551
# Epoch [182/500], Loss: 0.2498, Train Accuracy: 0.9056, Train F1: 0.8378, Test Accuracy: 0.8680, Test F1: 0.7627
# Epoch [182/500], Loss: 0.2498
# Epoch [183/500], Loss: 0.2531, Train Accuracy: 0.9019, Train F1: 0.8303, Test Accuracy: 0.8707, Test F1: 0.7598
# Epoch [183/500], Loss: 0.2531
# Epoch [184/500], Loss: 0.2553, Train Accuracy: 0.9023, Train F1: 0.8265, Test Accuracy: 0.8666, Test F1: 0.7663
# Epoch [184/500], Loss: 0.2553
# Epoch [185/500], Loss: 0.2513, Train Accuracy: 0.9041, Train F1: 0.8365, Test Accuracy: 0.8715, Test F1: 0.7650
# Epoch [185/500], Loss: 0.2513
# Epoch [186/500], Loss: 0.2479, Train Accuracy: 0.9040, Train F1: 0.8324, Test Accuracy: 0.8721, Test F1: 0.7646
# Epoch [186/500], Loss: 0.2479
# Epoch [187/500], Loss: 0.2481, Train Accuracy: 0.9021, Train F1: 0.8285, Test Accuracy: 0.8691, Test F1: 0.7692
# Epoch [187/500], Loss: 0.2481
# Epoch [188/500], Loss: 0.2462, Train Accuracy: 0.9052, Train F1: 0.8387, Test Accuracy: 0.8727, Test F1: 0.7671
# Epoch [188/500], Loss: 0.2462
# Epoch [189/500], Loss: 0.2434, Train Accuracy: 0.9057, Train F1: 0.8341, Test Accuracy: 0.8735, Test F1: 0.7705
# Epoch [189/500], Loss: 0.2434
# Epoch [190/500], Loss: 0.2456, Train Accuracy: 0.9051, Train F1: 0.8337, Test Accuracy: 0.8718, Test F1: 0.7725
# Epoch [190/500], Loss: 0.2456
# Epoch [191/500], Loss: 0.2442, Train Accuracy: 0.9088, Train F1: 0.8442, Test Accuracy: 0.8738, Test F1: 0.7665
# Epoch [191/500], Loss: 0.2442
# Epoch [192/500], Loss: 0.2427, Train Accuracy: 0.9051, Train F1: 0.8314, Test Accuracy: 0.8688, Test F1: 0.7686
# Epoch [192/500], Loss: 0.2427
# Epoch [193/500], Loss: 0.2371, Train Accuracy: 0.9108, Train F1: 0.8475, Test Accuracy: 0.8729, Test F1: 0.7684
# Epoch [193/500], Loss: 0.2371
# Epoch [194/500], Loss: 0.2396, Train Accuracy: 0.9078, Train F1: 0.8390, Test Accuracy: 0.8729, Test F1: 0.7674
# Epoch [194/500], Loss: 0.2396
# Epoch [195/500], Loss: 0.2394, Train Accuracy: 0.9069, Train F1: 0.8364, Test Accuracy: 0.8699, Test F1: 0.7719
# Epoch [195/500], Loss: 0.2394
# Epoch [196/500], Loss: 0.2376, Train Accuracy: 0.9073, Train F1: 0.8430, Test Accuracy: 0.8754, Test F1: 0.7695
# Epoch [196/500], Loss: 0.2376
# Epoch [197/500], Loss: 0.2359, Train Accuracy: 0.9099, Train F1: 0.8407, Test Accuracy: 0.8724, Test F1: 0.7740
# Epoch [197/500], Loss: 0.2359
# Epoch [198/500], Loss: 0.2347, Train Accuracy: 0.9114, Train F1: 0.8486, Test Accuracy: 0.8751, Test F1: 0.7742
# Epoch [198/500], Loss: 0.2347
# Epoch [199/500], Loss: 0.2314, Train Accuracy: 0.9112, Train F1: 0.8447, Test Accuracy: 0.8771, Test F1: 0.7776
# Epoch [199/500], Loss: 0.2314
# Epoch [200/500], Loss: 0.2331, Train Accuracy: 0.9099, Train F1: 0.8434, Test Accuracy: 0.8776, Test F1: 0.7793
# Epoch [200/500], Loss: 0.2331
# Epoch [201/500], Loss: 0.2310, Train Accuracy: 0.9105, Train F1: 0.8442, Test Accuracy: 0.8785, Test F1: 0.7807
# Epoch [201/500], Loss: 0.2310
# Epoch [202/500], Loss: 0.2348, Train Accuracy: 0.9118, Train F1: 0.8468, Test Accuracy: 0.8771, Test F1: 0.7781
# Epoch [202/500], Loss: 0.2348
# Epoch [203/500], Loss: 0.2322, Train Accuracy: 0.9124, Train F1: 0.8482, Test Accuracy: 0.8760, Test F1: 0.7756
# Epoch [203/500], Loss: 0.2322
# Epoch [204/500], Loss: 0.2283, Train Accuracy: 0.9146, Train F1: 0.8518, Test Accuracy: 0.8762, Test F1: 0.7782
# Epoch [204/500], Loss: 0.2283
# Epoch [205/500], Loss: 0.2269, Train Accuracy: 0.9139, Train F1: 0.8518, Test Accuracy: 0.8785, Test F1: 0.7778
# Epoch [205/500], Loss: 0.2269
# Epoch [206/500], Loss: 0.2333, Train Accuracy: 0.9100, Train F1: 0.8423, Test Accuracy: 0.8738, Test F1: 0.7763
# Epoch [206/500], Loss: 0.2333
# Epoch [207/500], Loss: 0.2229, Train Accuracy: 0.9162, Train F1: 0.8569, Test Accuracy: 0.8779, Test F1: 0.7756
# Epoch [207/500], Loss: 0.2229
# Epoch [208/500], Loss: 0.2252, Train Accuracy: 0.9141, Train F1: 0.8491, Test Accuracy: 0.8776, Test F1: 0.7812
# Epoch [208/500], Loss: 0.2252
# Epoch [209/500], Loss: 0.2206, Train Accuracy: 0.9180, Train F1: 0.8588, Test Accuracy: 0.8785, Test F1: 0.7804
# Epoch [209/500], Loss: 0.2206
# Epoch [210/500], Loss: 0.2252, Train Accuracy: 0.9153, Train F1: 0.8535, Test Accuracy: 0.8776, Test F1: 0.7775
# Epoch [210/500], Loss: 0.2252
# Epoch [211/500], Loss: 0.2232, Train Accuracy: 0.9150, Train F1: 0.8516, Test Accuracy: 0.8746, Test F1: 0.7779
# Epoch [211/500], Loss: 0.2232
# Epoch [212/500], Loss: 0.2212, Train Accuracy: 0.9175, Train F1: 0.8591, Test Accuracy: 0.8779, Test F1: 0.7743
# Epoch [212/500], Loss: 0.2212
# Epoch [213/500], Loss: 0.2213, Train Accuracy: 0.9177, Train F1: 0.8541, Test Accuracy: 0.8785, Test F1: 0.7862
# Epoch [213/500], Loss: 0.2213
# Epoch [214/500], Loss: 0.2201, Train Accuracy: 0.9177, Train F1: 0.8611, Test Accuracy: 0.8796, Test F1: 0.7769
# Epoch [214/500], Loss: 0.2201
# Epoch [215/500], Loss: 0.2165, Train Accuracy: 0.9180, Train F1: 0.8544, Test Accuracy: 0.8765, Test F1: 0.7808
# Epoch [215/500], Loss: 0.2165
# Epoch [216/500], Loss: 0.2176, Train Accuracy: 0.9170, Train F1: 0.8585, Test Accuracy: 0.8807, Test F1: 0.7818
# Epoch [216/500], Loss: 0.2176
# Epoch [217/500], Loss: 0.2128, Train Accuracy: 0.9192, Train F1: 0.8592, Test Accuracy: 0.8798, Test F1: 0.7820
# Epoch [217/500], Loss: 0.2128
# Epoch [218/500], Loss: 0.2124, Train Accuracy: 0.9195, Train F1: 0.8605, Test Accuracy: 0.8804, Test F1: 0.7893
# Epoch [218/500], Loss: 0.2124
# Epoch [219/500], Loss: 0.2146, Train Accuracy: 0.9169, Train F1: 0.8588, Test Accuracy: 0.8820, Test F1: 0.7807
# Epoch [219/500], Loss: 0.2146
# Epoch [220/500], Loss: 0.2149, Train Accuracy: 0.9202, Train F1: 0.8584, Test Accuracy: 0.8823, Test F1: 0.7901
# Epoch [220/500], Loss: 0.2149
# Epoch [221/500], Loss: 0.2085, Train Accuracy: 0.9232, Train F1: 0.8684, Test Accuracy: 0.8834, Test F1: 0.7886
# Epoch [221/500], Loss: 0.2085
# Epoch [222/500], Loss: 0.2092, Train Accuracy: 0.9229, Train F1: 0.8671, Test Accuracy: 0.8815, Test F1: 0.7828
# Epoch [222/500], Loss: 0.2092
# Epoch [223/500], Loss: 0.2068, Train Accuracy: 0.9210, Train F1: 0.8612, Test Accuracy: 0.8812, Test F1: 0.7917
# Epoch [223/500], Loss: 0.2068
# Epoch [224/500], Loss: 0.2087, Train Accuracy: 0.9230, Train F1: 0.8701, Test Accuracy: 0.8823, Test F1: 0.7804
# Epoch [224/500], Loss: 0.2087
# Epoch [225/500], Loss: 0.2101, Train Accuracy: 0.9203, Train F1: 0.8583, Test Accuracy: 0.8834, Test F1: 0.7939
# Epoch [225/500], Loss: 0.2101
# Epoch [226/500], Loss: 0.2067, Train Accuracy: 0.9220, Train F1: 0.8680, Test Accuracy: 0.8818, Test F1: 0.7830
# Epoch [226/500], Loss: 0.2067
# Epoch [227/500], Loss: 0.2085, Train Accuracy: 0.9219, Train F1: 0.8628, Test Accuracy: 0.8829, Test F1: 0.7901
# Epoch [227/500], Loss: 0.2085
# Epoch [228/500], Loss: 0.2045, Train Accuracy: 0.9229, Train F1: 0.8683, Test Accuracy: 0.8843, Test F1: 0.7891
# Epoch [228/500], Loss: 0.2045
# Epoch [229/500], Loss: 0.2040, Train Accuracy: 0.9234, Train F1: 0.8676, Test Accuracy: 0.8840, Test F1: 0.7892
# Epoch [229/500], Loss: 0.2040
# Epoch [230/500], Loss: 0.2036, Train Accuracy: 0.9245, Train F1: 0.8692, Test Accuracy: 0.8831, Test F1: 0.7888
# Epoch [230/500], Loss: 0.2036
# Epoch [231/500], Loss: 0.2042, Train Accuracy: 0.9244, Train F1: 0.8699, Test Accuracy: 0.8831, Test F1: 0.7882
# Epoch [231/500], Loss: 0.2042
# Epoch [232/500], Loss: 0.1977, Train Accuracy: 0.9283, Train F1: 0.8759, Test Accuracy: 0.8843, Test F1: 0.7885
# Epoch [232/500], Loss: 0.1977
# Epoch [233/500], Loss: 0.2008, Train Accuracy: 0.9249, Train F1: 0.8692, Test Accuracy: 0.8848, Test F1: 0.7928
# Epoch [233/500], Loss: 0.2008
# Epoch [234/500], Loss: 0.1985, Train Accuracy: 0.9245, Train F1: 0.8707, Test Accuracy: 0.8845, Test F1: 0.7885
# Epoch [234/500], Loss: 0.1985
# Epoch [235/500], Loss: 0.1973, Train Accuracy: 0.9255, Train F1: 0.8706, Test Accuracy: 0.8854, Test F1: 0.7911
# Epoch [235/500], Loss: 0.1973
# Epoch [236/500], Loss: 0.1997, Train Accuracy: 0.9239, Train F1: 0.8686, Test Accuracy: 0.8843, Test F1: 0.7891
# Epoch [236/500], Loss: 0.1997
# Epoch [237/500], Loss: 0.1985, Train Accuracy: 0.9255, Train F1: 0.8712, Test Accuracy: 0.8870, Test F1: 0.7946
# Epoch [237/500], Loss: 0.1985
# Epoch [238/500], Loss: 0.2003, Train Accuracy: 0.9245, Train F1: 0.8691, Test Accuracy: 0.8881, Test F1: 0.7992
# Epoch [238/500], Loss: 0.2003
# Epoch [239/500], Loss: 0.1973, Train Accuracy: 0.9271, Train F1: 0.8748, Test Accuracy: 0.8884, Test F1: 0.7968
# Epoch [239/500], Loss: 0.1973
# Epoch [240/500], Loss: 0.1950, Train Accuracy: 0.9261, Train F1: 0.8715, Test Accuracy: 0.8873, Test F1: 0.7960
# Epoch [240/500], Loss: 0.1950
# Epoch [241/500], Loss: 0.1952, Train Accuracy: 0.9255, Train F1: 0.8712, Test Accuracy: 0.8878, Test F1: 0.7982
# Epoch [241/500], Loss: 0.1952
# Epoch [242/500], Loss: 0.1935, Train Accuracy: 0.9289, Train F1: 0.8781, Test Accuracy: 0.8873, Test F1: 0.7946
# Epoch [242/500], Loss: 0.1935
# Epoch [243/500], Loss: 0.1961, Train Accuracy: 0.9243, Train F1: 0.8686, Test Accuracy: 0.8862, Test F1: 0.7954
# Epoch [243/500], Loss: 0.1961
# Epoch [244/500], Loss: 0.1924, Train Accuracy: 0.9285, Train F1: 0.8777, Test Accuracy: 0.8878, Test F1: 0.7958
# Epoch [244/500], Loss: 0.1924
# Epoch [245/500], Loss: 0.1916, Train Accuracy: 0.9299, Train F1: 0.8790, Test Accuracy: 0.8873, Test F1: 0.7944
# Epoch [245/500], Loss: 0.1916
# Epoch [246/500], Loss: 0.1918, Train Accuracy: 0.9293, Train F1: 0.8772, Test Accuracy: 0.8909, Test F1: 0.8051
# Epoch [246/500], Loss: 0.1918
# Epoch [247/500], Loss: 0.1902, Train Accuracy: 0.9278, Train F1: 0.8769, Test Accuracy: 0.8867, Test F1: 0.7919
# Epoch [247/500], Loss: 0.1902
# Epoch [248/500], Loss: 0.1891, Train Accuracy: 0.9305, Train F1: 0.8786, Test Accuracy: 0.8873, Test F1: 0.7966
# Epoch [248/500], Loss: 0.1891
# Epoch [249/500], Loss: 0.1892, Train Accuracy: 0.9289, Train F1: 0.8780, Test Accuracy: 0.8867, Test F1: 0.7952
# Epoch [249/500], Loss: 0.1892
# Epoch [250/500], Loss: 0.1881, Train Accuracy: 0.9325, Train F1: 0.8838, Test Accuracy: 0.8881, Test F1: 0.7966
# Epoch [250/500], Loss: 0.1881
# Epoch [251/500], Loss: 0.1871, Train Accuracy: 0.9317, Train F1: 0.8814, Test Accuracy: 0.8878, Test F1: 0.7970
# Epoch [251/500], Loss: 0.1871
# Epoch [252/500], Loss: 0.1866, Train Accuracy: 0.9296, Train F1: 0.8787, Test Accuracy: 0.8887, Test F1: 0.7966
# Epoch [252/500], Loss: 0.1866
# Epoch [253/500], Loss: 0.1854, Train Accuracy: 0.9278, Train F1: 0.8749, Test Accuracy: 0.8909, Test F1: 0.8026
# Epoch [253/500], Loss: 0.1854
# Epoch [254/500], Loss: 0.1847, Train Accuracy: 0.9294, Train F1: 0.8781, Test Accuracy: 0.8909, Test F1: 0.8036
# Epoch [254/500], Loss: 0.1847
# Epoch [255/500], Loss: 0.1850, Train Accuracy: 0.9323, Train F1: 0.8844, Test Accuracy: 0.8884, Test F1: 0.7935
# Epoch [255/500], Loss: 0.1850
# Epoch [256/500], Loss: 0.1821, Train Accuracy: 0.9331, Train F1: 0.8826, Test Accuracy: 0.8909, Test F1: 0.8059
# Epoch [256/500], Loss: 0.1821
# Epoch [257/500], Loss: 0.1825, Train Accuracy: 0.9316, Train F1: 0.8842, Test Accuracy: 0.8865, Test F1: 0.7885
# Epoch [257/500], Loss: 0.1825
# Epoch [258/500], Loss: 0.1883, Train Accuracy: 0.9283, Train F1: 0.8730, Test Accuracy: 0.8925, Test F1: 0.8113
# Epoch [258/500], Loss: 0.1883
# Epoch [259/500], Loss: 0.1832, Train Accuracy: 0.9309, Train F1: 0.8837, Test Accuracy: 0.8878, Test F1: 0.7937
# Epoch [259/500], Loss: 0.1832
# Epoch [260/500], Loss: 0.1821, Train Accuracy: 0.9327, Train F1: 0.8817, Test Accuracy: 0.8920, Test F1: 0.8075
# Epoch [260/500], Loss: 0.1821
# Epoch [261/500], Loss: 0.1785, Train Accuracy: 0.9357, Train F1: 0.8906, Test Accuracy: 0.8878, Test F1: 0.7949
# Epoch [261/500], Loss: 0.1785
# Epoch [262/500], Loss: 0.1830, Train Accuracy: 0.9311, Train F1: 0.8799, Test Accuracy: 0.8890, Test F1: 0.8004
# Epoch [262/500], Loss: 0.1830
# Epoch [263/500], Loss: 0.1785, Train Accuracy: 0.9349, Train F1: 0.8881, Test Accuracy: 0.8892, Test F1: 0.7972
# Epoch [263/500], Loss: 0.1785
# Epoch [264/500], Loss: 0.1766, Train Accuracy: 0.9340, Train F1: 0.8858, Test Accuracy: 0.8906, Test F1: 0.8010
# Epoch [264/500], Loss: 0.1766
# Epoch [265/500], Loss: 0.1803, Train Accuracy: 0.9317, Train F1: 0.8822, Test Accuracy: 0.8920, Test F1: 0.8060
# Epoch [265/500], Loss: 0.1803
# Epoch [266/500], Loss: 0.1776, Train Accuracy: 0.9340, Train F1: 0.8868, Test Accuracy: 0.8906, Test F1: 0.8008
# Epoch [266/500], Loss: 0.1776
# Epoch [267/500], Loss: 0.1757, Train Accuracy: 0.9370, Train F1: 0.8908, Test Accuracy: 0.8923, Test F1: 0.8069
# Epoch [267/500], Loss: 0.1757
# Epoch [268/500], Loss: 0.1741, Train Accuracy: 0.9350, Train F1: 0.8887, Test Accuracy: 0.8912, Test F1: 0.8022
# Epoch [268/500], Loss: 0.1741
# Epoch [269/500], Loss: 0.1754, Train Accuracy: 0.9360, Train F1: 0.8888, Test Accuracy: 0.8928, Test F1: 0.8073
# Epoch [269/500], Loss: 0.1754
# Epoch [270/500], Loss: 0.1739, Train Accuracy: 0.9380, Train F1: 0.8938, Test Accuracy: 0.8917, Test F1: 0.8020
# Epoch [270/500], Loss: 0.1739
# Epoch [271/500], Loss: 0.1749, Train Accuracy: 0.9333, Train F1: 0.8839, Test Accuracy: 0.8912, Test F1: 0.8046
# Epoch [271/500], Loss: 0.1749
# Epoch [272/500], Loss: 0.1699, Train Accuracy: 0.9374, Train F1: 0.8917, Test Accuracy: 0.8912, Test F1: 0.8036
# Epoch [272/500], Loss: 0.1699
# Epoch [273/500], Loss: 0.1736, Train Accuracy: 0.9378, Train F1: 0.8925, Test Accuracy: 0.8903, Test F1: 0.7996
# Epoch [273/500], Loss: 0.1736
# Epoch [274/500], Loss: 0.1784, Train Accuracy: 0.9337, Train F1: 0.8854, Test Accuracy: 0.8934, Test F1: 0.8102
# Epoch [274/500], Loss: 0.1784
# Epoch [275/500], Loss: 0.1699, Train Accuracy: 0.9368, Train F1: 0.8927, Test Accuracy: 0.8884, Test F1: 0.7932
# Epoch [275/500], Loss: 0.1699
# Epoch [276/500], Loss: 0.1717, Train Accuracy: 0.9367, Train F1: 0.8892, Test Accuracy: 0.8942, Test F1: 0.8111
# Epoch [276/500], Loss: 0.1717
# Epoch [277/500], Loss: 0.1683, Train Accuracy: 0.9392, Train F1: 0.8961, Test Accuracy: 0.8925, Test F1: 0.8060
# Epoch [277/500], Loss: 0.1683
# Epoch [278/500], Loss: 0.1703, Train Accuracy: 0.9380, Train F1: 0.8932, Test Accuracy: 0.8909, Test F1: 0.7990
# Epoch [278/500], Loss: 0.1703
# Epoch [279/500], Loss: 0.1703, Train Accuracy: 0.9388, Train F1: 0.8927, Test Accuracy: 0.8923, Test F1: 0.8103
# Epoch [279/500], Loss: 0.1703
# Epoch [280/500], Loss: 0.1686, Train Accuracy: 0.9379, Train F1: 0.8948, Test Accuracy: 0.8903, Test F1: 0.7971
# Epoch [280/500], Loss: 0.1686
# Epoch [281/500], Loss: 0.1707, Train Accuracy: 0.9354, Train F1: 0.8864, Test Accuracy: 0.8920, Test F1: 0.8081
# Epoch [281/500], Loss: 0.1707
# Epoch [282/500], Loss: 0.1690, Train Accuracy: 0.9368, Train F1: 0.8929, Test Accuracy: 0.8914, Test F1: 0.7998
# Epoch [282/500], Loss: 0.1690
# Epoch [283/500], Loss: 0.1689, Train Accuracy: 0.9379, Train F1: 0.8913, Test Accuracy: 0.8920, Test F1: 0.8063
# Epoch [283/500], Loss: 0.1689
# Epoch [284/500], Loss: 0.1649, Train Accuracy: 0.9402, Train F1: 0.8976, Test Accuracy: 0.8931, Test F1: 0.8054
# Epoch [284/500], Loss: 0.1649
# Epoch [285/500], Loss: 0.1650, Train Accuracy: 0.9390, Train F1: 0.8949, Test Accuracy: 0.8901, Test F1: 0.7959
# Epoch [285/500], Loss: 0.1650
# Epoch [286/500], Loss: 0.1649, Train Accuracy: 0.9404, Train F1: 0.8955, Test Accuracy: 0.8925, Test F1: 0.8096
# Epoch [286/500], Loss: 0.1649
# Epoch [287/500], Loss: 0.1633, Train Accuracy: 0.9404, Train F1: 0.8993, Test Accuracy: 0.8881, Test F1: 0.7916
# Epoch [287/500], Loss: 0.1633
# Epoch [288/500], Loss: 0.1697, Train Accuracy: 0.9352, Train F1: 0.8861, Test Accuracy: 0.8939, Test F1: 0.8118
# Epoch [288/500], Loss: 0.1697
# Epoch [289/500], Loss: 0.1671, Train Accuracy: 0.9374, Train F1: 0.8937, Test Accuracy: 0.8920, Test F1: 0.8026
# Epoch [289/500], Loss: 0.1671
# Epoch [290/500], Loss: 0.1619, Train Accuracy: 0.9408, Train F1: 0.8975, Test Accuracy: 0.8923, Test F1: 0.8028
# Epoch [290/500], Loss: 0.1619
# Epoch [291/500], Loss: 0.1653, Train Accuracy: 0.9407, Train F1: 0.8974, Test Accuracy: 0.8939, Test F1: 0.8114
# Epoch [291/500], Loss: 0.1653
# Epoch [292/500], Loss: 0.1609, Train Accuracy: 0.9411, Train F1: 0.9004, Test Accuracy: 0.8920, Test F1: 0.7977
# Epoch [292/500], Loss: 0.1609
# Epoch [293/500], Loss: 0.1715, Train Accuracy: 0.9354, Train F1: 0.8854, Test Accuracy: 0.8942, Test F1: 0.8151
# Epoch [293/500], Loss: 0.1715
# Epoch [294/500], Loss: 0.1684, Train Accuracy: 0.9374, Train F1: 0.8952, Test Accuracy: 0.8901, Test F1: 0.7940
# Epoch [294/500], Loss: 0.1684
# Epoch [295/500], Loss: 0.1655, Train Accuracy: 0.9396, Train F1: 0.8932, Test Accuracy: 0.8950, Test F1: 0.8106
# Epoch [295/500], Loss: 0.1655
# Epoch [296/500], Loss: 0.1651, Train Accuracy: 0.9370, Train F1: 0.8910, Test Accuracy: 0.8942, Test F1: 0.8125
# Epoch [296/500], Loss: 0.1651
# Epoch [297/500], Loss: 0.1636, Train Accuracy: 0.9404, Train F1: 0.8990, Test Accuracy: 0.8881, Test F1: 0.7907
# Epoch [297/500], Loss: 0.1636
# Epoch [298/500], Loss: 0.1649, Train Accuracy: 0.9387, Train F1: 0.8919, Test Accuracy: 0.8948, Test F1: 0.8130
# Epoch [298/500], Loss: 0.1649
# Epoch [299/500], Loss: 0.1625, Train Accuracy: 0.9401, Train F1: 0.8986, Test Accuracy: 0.8917, Test F1: 0.8018
# Epoch [299/500], Loss: 0.1625
# Epoch [300/500], Loss: 0.1606, Train Accuracy: 0.9388, Train F1: 0.8942, Test Accuracy: 0.8912, Test F1: 0.7998
# Epoch [300/500], Loss: 0.1606
# Epoch [301/500], Loss: 0.1634, Train Accuracy: 0.9385, Train F1: 0.8935, Test Accuracy: 0.8964, Test F1: 0.8168
# Epoch [301/500], Loss: 0.1634
# Epoch [302/500], Loss: 0.1611, Train Accuracy: 0.9410, Train F1: 0.9007, Test Accuracy: 0.8925, Test F1: 0.8002
# Epoch [302/500], Loss: 0.1611
# Epoch [303/500], Loss: 0.1617, Train Accuracy: 0.9380, Train F1: 0.8921, Test Accuracy: 0.8953, Test F1: 0.8115
# Epoch [303/500], Loss: 0.1617
# Epoch [304/500], Loss: 0.1569, Train Accuracy: 0.9425, Train F1: 0.9016, Test Accuracy: 0.8956, Test F1: 0.8106
# Epoch [304/500], Loss: 0.1569
# Epoch [305/500], Loss: 0.1599, Train Accuracy: 0.9405, Train F1: 0.8980, Test Accuracy: 0.8903, Test F1: 0.7959
# Epoch [305/500], Loss: 0.1599
# Epoch [306/500], Loss: 0.1580, Train Accuracy: 0.9399, Train F1: 0.8945, Test Accuracy: 0.8970, Test F1: 0.8187
# Epoch [306/500], Loss: 0.1580
# Epoch [307/500], Loss: 0.1591, Train Accuracy: 0.9415, Train F1: 0.9015, Test Accuracy: 0.8909, Test F1: 0.7967
# Epoch [307/500], Loss: 0.1591
# Epoch [308/500], Loss: 0.1624, Train Accuracy: 0.9401, Train F1: 0.8948, Test Accuracy: 0.8917, Test F1: 0.8042
# Epoch [308/500], Loss: 0.1624
# Epoch [309/500], Loss: 0.1560, Train Accuracy: 0.9394, Train F1: 0.8960, Test Accuracy: 0.8936, Test F1: 0.8095
# Epoch [309/500], Loss: 0.1560
# Epoch [310/500], Loss: 0.1567, Train Accuracy: 0.9437, Train F1: 0.9036, Test Accuracy: 0.8914, Test F1: 0.8006
# Epoch [310/500], Loss: 0.1567
# Epoch [311/500], Loss: 0.1575, Train Accuracy: 0.9422, Train F1: 0.8992, Test Accuracy: 0.8936, Test F1: 0.8101
# Epoch [311/500], Loss: 0.1575
# Epoch [312/500], Loss: 0.1537, Train Accuracy: 0.9449, Train F1: 0.9066, Test Accuracy: 0.8914, Test F1: 0.7998
# Epoch [312/500], Loss: 0.1537
# Epoch [313/500], Loss: 0.1559, Train Accuracy: 0.9432, Train F1: 0.9010, Test Accuracy: 0.8948, Test F1: 0.8102
# Epoch [313/500], Loss: 0.1559
# Epoch [314/500], Loss: 0.1557, Train Accuracy: 0.9430, Train F1: 0.9023, Test Accuracy: 0.8948, Test F1: 0.8086
# Epoch [314/500], Loss: 0.1557
# Epoch [315/500], Loss: 0.1542, Train Accuracy: 0.9438, Train F1: 0.9031, Test Accuracy: 0.8942, Test F1: 0.8090
# Epoch [315/500], Loss: 0.1542
# Epoch [316/500], Loss: 0.1510, Train Accuracy: 0.9447, Train F1: 0.9049, Test Accuracy: 0.8934, Test F1: 0.8058
# Epoch [316/500], Loss: 0.1510
# Epoch [317/500], Loss: 0.1536, Train Accuracy: 0.9447, Train F1: 0.9044, Test Accuracy: 0.8936, Test F1: 0.8058
# Epoch [317/500], Loss: 0.1536
# Epoch [318/500], Loss: 0.1510, Train Accuracy: 0.9445, Train F1: 0.9042, Test Accuracy: 0.8942, Test F1: 0.8092
# Epoch [318/500], Loss: 0.1510
# Epoch [319/500], Loss: 0.1502, Train Accuracy: 0.9462, Train F1: 0.9079, Test Accuracy: 0.8934, Test F1: 0.8066
# Epoch [319/500], Loss: 0.1502
# Epoch [320/500], Loss: 0.1538, Train Accuracy: 0.9446, Train F1: 0.9045, Test Accuracy: 0.8936, Test F1: 0.8062
# Epoch [320/500], Loss: 0.1538
# Epoch [321/500], Loss: 0.1498, Train Accuracy: 0.9439, Train F1: 0.9027, Test Accuracy: 0.8936, Test F1: 0.8089
# Epoch [321/500], Loss: 0.1498
# Epoch [322/500], Loss: 0.1508, Train Accuracy: 0.9451, Train F1: 0.9059, Test Accuracy: 0.8945, Test F1: 0.8071
# Epoch [322/500], Loss: 0.1508
# Epoch [323/500], Loss: 0.1467, Train Accuracy: 0.9453, Train F1: 0.9054, Test Accuracy: 0.8942, Test F1: 0.8063
# Epoch [323/500], Loss: 0.1467
# Epoch [324/500], Loss: 0.1459, Train Accuracy: 0.9460, Train F1: 0.9068, Test Accuracy: 0.8994, Test F1: 0.8200
# Epoch [324/500], Loss: 0.1459
# Epoch [325/500], Loss: 0.1486, Train Accuracy: 0.9440, Train F1: 0.9049, Test Accuracy: 0.8909, Test F1: 0.7965
# Epoch [325/500], Loss: 0.1486
# Epoch [326/500], Loss: 0.1535, Train Accuracy: 0.9434, Train F1: 0.9008, Test Accuracy: 0.8978, Test F1: 0.8179
# Epoch [326/500], Loss: 0.1535
# Epoch [327/500], Loss: 0.1451, Train Accuracy: 0.9456, Train F1: 0.9080, Test Accuracy: 0.8931, Test F1: 0.8020
# Epoch [327/500], Loss: 0.1451
# Epoch [328/500], Loss: 0.1525, Train Accuracy: 0.9432, Train F1: 0.9007, Test Accuracy: 0.8967, Test F1: 0.8141
# Epoch [328/500], Loss: 0.1525
# Epoch [329/500], Loss: 0.1502, Train Accuracy: 0.9436, Train F1: 0.9037, Test Accuracy: 0.8964, Test F1: 0.8128
# Epoch [329/500], Loss: 0.1502
# Epoch [330/500], Loss: 0.1441, Train Accuracy: 0.9487, Train F1: 0.9122, Test Accuracy: 0.8934, Test F1: 0.8027
# Epoch [330/500], Loss: 0.1441
# Epoch [331/500], Loss: 0.1502, Train Accuracy: 0.9448, Train F1: 0.9036, Test Accuracy: 0.8978, Test F1: 0.8192
# Epoch [331/500], Loss: 0.1502
# Epoch [332/500], Loss: 0.1421, Train Accuracy: 0.9471, Train F1: 0.9103, Test Accuracy: 0.8945, Test F1: 0.8065
# Epoch [332/500], Loss: 0.1421
# Epoch [333/500], Loss: 0.1460, Train Accuracy: 0.9478, Train F1: 0.9093, Test Accuracy: 0.8939, Test F1: 0.8055
# Epoch [333/500], Loss: 0.1460
# Epoch [334/500], Loss: 0.1447, Train Accuracy: 0.9469, Train F1: 0.9076, Test Accuracy: 0.8994, Test F1: 0.8217
# Epoch [334/500], Loss: 0.1447
# Epoch [335/500], Loss: 0.1468, Train Accuracy: 0.9464, Train F1: 0.9094, Test Accuracy: 0.8928, Test F1: 0.7992
# Epoch [335/500], Loss: 0.1468
# Epoch [336/500], Loss: 0.1470, Train Accuracy: 0.9461, Train F1: 0.9055, Test Accuracy: 0.8994, Test F1: 0.8171
# Epoch [336/500], Loss: 0.1470
# Epoch [337/500], Loss: 0.1423, Train Accuracy: 0.9489, Train F1: 0.9118, Test Accuracy: 0.8992, Test F1: 0.8208
# Epoch [337/500], Loss: 0.1423
# Epoch [338/500], Loss: 0.1457, Train Accuracy: 0.9469, Train F1: 0.9099, Test Accuracy: 0.8906, Test F1: 0.7950
# Epoch [338/500], Loss: 0.1457
# Epoch [339/500], Loss: 0.1466, Train Accuracy: 0.9446, Train F1: 0.9018, Test Accuracy: 0.8972, Test F1: 0.8164
# Epoch [339/500], Loss: 0.1466
# ...
# Epoch [388/500], Loss: 0.1250
# Epoch [389/500], Loss: 0.1247, Train Accuracy: 0.9546, Train F1: 0.9210, Test Accuracy: 0.8994, Test F1: 0.8173
# Epoch [389/500], Loss: 0.1247
# Epoch [390/500], Loss: 0.1244, Train Accuracy: 0.9538, Train F1: 0.9201, Test Accuracy: 0.9022, Test F1: 0.8239
# Epoch [390/500], Loss: 0.1244
# Epoch [391/500], Loss: 0.1269, Train Accuracy: 0.9526, Train F1: 0.9191, Test Accuracy: 0.8981, Test F1: 0.8091
# Epoch [391/500], Loss: 0.1269
# Epoch [392/500], Loss: 0.1308, Train Accuracy: 0.9507, Train F1: 0.9135, Test Accuracy: 0.9011, Test F1: 0.8183
# Epoch [392/500], Loss: 0.1308
# Epoch [393/500], Loss: 0.1262, Train Accuracy: 0.9533, Train F1: 0.9196, Test Accuracy: 0.9008, Test F1: 0.8201
# Epoch [393/500], Loss: 0.1262
# Epoch [394/500], Loss: 0.1264, Train Accuracy: 0.9523, Train F1: 0.9182, Test Accuracy: 0.8994, Test F1: 0.8131
# Epoch [394/500], Loss: 0.1264
# Epoch [395/500], Loss: 0.1281, Train Accuracy: 0.9505, Train F1: 0.9145, Test Accuracy: 0.8992, Test F1: 0.8141
# Epoch [395/500], Loss: 0.1281
# Epoch [396/500], Loss: 0.1275, Train Accuracy: 0.9529, Train F1: 0.9180, Test Accuracy: 0.8986, Test F1: 0.8170
# Epoch [396/500], Loss: 0.1275
# Epoch [397/500], Loss: 0.1254, Train Accuracy: 0.9535, Train F1: 0.9201, Test Accuracy: 0.8950, Test F1: 0.8055
# Epoch [397/500], Loss: 0.1254
# Epoch [398/500], Loss: 0.1252, Train Accuracy: 0.9540, Train F1: 0.9200, Test Accuracy: 0.8967, Test F1: 0.8107
# Epoch [398/500], Loss: 0.1252
# Epoch [399/500], Loss: 0.1195, Train Accuracy: 0.9559, Train F1: 0.9237, Test Accuracy: 0.8981, Test F1: 0.8149
# Epoch [399/500], Loss: 0.1195
# Epoch [400/500], Loss: 0.1219, Train Accuracy: 0.9549, Train F1: 0.9228, Test Accuracy: 0.8950, Test F1: 0.8039
# Epoch [400/500], Loss: 0.1219
# Epoch [401/500], Loss: 0.1274, Train Accuracy: 0.9541, Train F1: 0.9200, Test Accuracy: 0.9000, Test F1: 0.8179
# Epoch [401/500], Loss: 0.1274
# Epoch [402/500], Loss: 0.1253, Train Accuracy: 0.9539, Train F1: 0.9209, Test Accuracy: 0.9022, Test F1: 0.8225
# Epoch [402/500], Loss: 0.1253
# Epoch [403/500], Loss: 0.1213, Train Accuracy: 0.9539, Train F1: 0.9209, Test Accuracy: 0.8975, Test F1: 0.8106
# Epoch [403/500], Loss: 0.1213
# Epoch [404/500], Loss: 0.1219, Train Accuracy: 0.9533, Train F1: 0.9190, Test Accuracy: 0.8997, Test F1: 0.8168
# Epoch [404/500], Loss: 0.1219
# Epoch [405/500], Loss: 0.1194, Train Accuracy: 0.9554, Train F1: 0.9230, Test Accuracy: 0.8994, Test F1: 0.8165
# Epoch [405/500], Loss: 0.1194
# Epoch [406/500], Loss: 0.1238, Train Accuracy: 0.9542, Train F1: 0.9212, Test Accuracy: 0.8950, Test F1: 0.8033
# Epoch [406/500], Loss: 0.1238
# Epoch [407/500], Loss: 0.1233, Train Accuracy: 0.9544, Train F1: 0.9205, Test Accuracy: 0.8975, Test F1: 0.8135
# Epoch [407/500], Loss: 0.1233
# Epoch [408/500], Loss: 0.1204, Train Accuracy: 0.9559, Train F1: 0.9239, Test Accuracy: 0.8989, Test F1: 0.8159
# Epoch [408/500], Loss: 0.1204
# Epoch [409/500], Loss: 0.1196, Train Accuracy: 0.9557, Train F1: 0.9240, Test Accuracy: 0.8945, Test F1: 0.8015
# Epoch [409/500], Loss: 0.1196
# Epoch [410/500], Loss: 0.1256, Train Accuracy: 0.9511, Train F1: 0.9144, Test Accuracy: 0.9008, Test F1: 0.8184
# Epoch [410/500], Loss: 0.1256
# Epoch [411/500], Loss: 0.1198, Train Accuracy: 0.9558, Train F1: 0.9239, Test Accuracy: 0.9000, Test F1: 0.8161
# Epoch [411/500], Loss: 0.1198
# Epoch [412/500], Loss: 0.1277, Train Accuracy: 0.9517, Train F1: 0.9168, Test Accuracy: 0.8994, Test F1: 0.8124
# Epoch [412/500], Loss: 0.1277
# Epoch [413/500], Loss: 0.1228, Train Accuracy: 0.9544, Train F1: 0.9203, Test Accuracy: 0.9011, Test F1: 0.8196
# Epoch [413/500], Loss: 0.1228
# Epoch [414/500], Loss: 0.1186, Train Accuracy: 0.9558, Train F1: 0.9240, Test Accuracy: 0.8983, Test F1: 0.8109
# Epoch [414/500], Loss: 0.1186
# Epoch [415/500], Loss: 0.1211, Train Accuracy: 0.9550, Train F1: 0.9215, Test Accuracy: 0.8970, Test F1: 0.8078
# Epoch [415/500], Loss: 0.1211
# Epoch [416/500], Loss: 0.1183, Train Accuracy: 0.9557, Train F1: 0.9228, Test Accuracy: 0.8978, Test F1: 0.8133
# Epoch [416/500], Loss: 0.1183
# Epoch [417/500], Loss: 0.1188, Train Accuracy: 0.9549, Train F1: 0.9226, Test Accuracy: 0.8983, Test F1: 0.8122
# Epoch [417/500], Loss: 0.1188
# Epoch [418/500], Loss: 0.1231, Train Accuracy: 0.9527, Train F1: 0.9185, Test Accuracy: 0.8986, Test F1: 0.8107
# Epoch [418/500], Loss: 0.1231
# Epoch [419/500], Loss: 0.1181, Train Accuracy: 0.9549, Train F1: 0.9218, Test Accuracy: 0.8997, Test F1: 0.8151
# Epoch [419/500], Loss: 0.1181
# Epoch [420/500], Loss: 0.1173, Train Accuracy: 0.9557, Train F1: 0.9237, Test Accuracy: 0.8983, Test F1: 0.8122
# Epoch [420/500], Loss: 0.1173
# Epoch [421/500], Loss: 0.1167, Train Accuracy: 0.9574, Train F1: 0.9263, Test Accuracy: 0.8992, Test F1: 0.8121
# Epoch [421/500], Loss: 0.1167
# Epoch [422/500], Loss: 0.1199, Train Accuracy: 0.9531, Train F1: 0.9184, Test Accuracy: 0.9000, Test F1: 0.8159
# Epoch [422/500], Loss: 0.1199
# Epoch [423/500], Loss: 0.1173, Train Accuracy: 0.9549, Train F1: 0.9219, Test Accuracy: 0.8992, Test F1: 0.8141
# Epoch [423/500], Loss: 0.1173
# Epoch [424/500], Loss: 0.1116, Train Accuracy: 0.9582, Train F1: 0.9276, Test Accuracy: 0.8967, Test F1: 0.8052
# Epoch [424/500], Loss: 0.1116
# Epoch [425/500], Loss: 0.1158, Train Accuracy: 0.9559, Train F1: 0.9231, Test Accuracy: 0.8997, Test F1: 0.8147
# Epoch [425/500], Loss: 0.1158
# Epoch [426/500], Loss: 0.1202, Train Accuracy: 0.9557, Train F1: 0.9233, Test Accuracy: 0.9000, Test F1: 0.8162
# Epoch [426/500], Loss: 0.1202
# Epoch [427/500], Loss: 0.1166, Train Accuracy: 0.9564, Train F1: 0.9250, Test Accuracy: 0.8970, Test F1: 0.8056
# Epoch [427/500], Loss: 0.1166
# Epoch [428/500], Loss: 0.1159, Train Accuracy: 0.9563, Train F1: 0.9234, Test Accuracy: 0.8978, Test F1: 0.8085
# Epoch [428/500], Loss: 0.1159
# Epoch [429/500], Loss: 0.1125, Train Accuracy: 0.9584, Train F1: 0.9274, Test Accuracy: 0.9008, Test F1: 0.8186
# Epoch [429/500], Loss: 0.1125
# Epoch [430/500], Loss: 0.1141, Train Accuracy: 0.9568, Train F1: 0.9257, Test Accuracy: 0.8967, Test F1: 0.8058
# Epoch [430/500], Loss: 0.1141
# Epoch [431/500], Loss: 0.1165, Train Accuracy: 0.9563, Train F1: 0.9236, Test Accuracy: 0.9003, Test F1: 0.8159
# Epoch [431/500], Loss: 0.1165
# Epoch [432/500], Loss: 0.1125, Train Accuracy: 0.9574, Train F1: 0.9265, Test Accuracy: 0.8997, Test F1: 0.8132
# Epoch [432/500], Loss: 0.1125
# Epoch [433/500], Loss: 0.1127, Train Accuracy: 0.9579, Train F1: 0.9266, Test Accuracy: 0.8994, Test F1: 0.8152
# Epoch [433/500], Loss: 0.1127
# Epoch [434/500], Loss: 0.1173, Train Accuracy: 0.9564, Train F1: 0.9246, Test Accuracy: 0.8989, Test F1: 0.8135
# Epoch [434/500], Loss: 0.1173
# Epoch [435/500], Loss: 0.1108, Train Accuracy: 0.9584, Train F1: 0.9279, Test Accuracy: 0.8978, Test F1: 0.8106
# Epoch [435/500], Loss: 0.1108
# Epoch [436/500], Loss: 0.1149, Train Accuracy: 0.9571, Train F1: 0.9257, Test Accuracy: 0.8992, Test F1: 0.8144
# Epoch [436/500], Loss: 0.1149
# Epoch [437/500], Loss: 0.1090, Train Accuracy: 0.9582, Train F1: 0.9276, Test Accuracy: 0.8989, Test F1: 0.8148
# Epoch [437/500], Loss: 0.1090
# Epoch [438/500], Loss: 0.1126, Train Accuracy: 0.9571, Train F1: 0.9262, Test Accuracy: 0.8961, Test F1: 0.8060
# Epoch [438/500], Loss: 0.1126
# Epoch [439/500], Loss: 0.1119, Train Accuracy: 0.9571, Train F1: 0.9255, Test Accuracy: 0.8975, Test F1: 0.8079
# Epoch [439/500], Loss: 0.1119
# Epoch [440/500], Loss: 0.1131, Train Accuracy: 0.9571, Train F1: 0.9256, Test Accuracy: 0.8970, Test F1: 0.8072
# Epoch [440/500], Loss: 0.1131
# Epoch [441/500], Loss: 0.1087, Train Accuracy: 0.9590, Train F1: 0.9286, Test Accuracy: 0.8981, Test F1: 0.8116
# Epoch [441/500], Loss: 0.1087
# Epoch [442/500], Loss: 0.1084, Train Accuracy: 0.9578, Train F1: 0.9269, Test Accuracy: 0.8997, Test F1: 0.8160
# Epoch [442/500], Loss: 0.1084
# Epoch [443/500], Loss: 0.1109, Train Accuracy: 0.9590, Train F1: 0.9295, Test Accuracy: 0.8989, Test F1: 0.8108
# Epoch [443/500], Loss: 0.1109
# Epoch [444/500], Loss: 0.1127, Train Accuracy: 0.9579, Train F1: 0.9269, Test Accuracy: 0.8986, Test F1: 0.8121
# Epoch [444/500], Loss: 0.1127
# Epoch [445/500], Loss: 0.1084, Train Accuracy: 0.9589, Train F1: 0.9289, Test Accuracy: 0.8992, Test F1: 0.8135
# Epoch [445/500], Loss: 0.1084
# Epoch [446/500], Loss: 0.1113, Train Accuracy: 0.9588, Train F1: 0.9290, Test Accuracy: 0.8989, Test F1: 0.8106
# Epoch [446/500], Loss: 0.1113
# Epoch [447/500], Loss: 0.1121, Train Accuracy: 0.9584, Train F1: 0.9273, Test Accuracy: 0.9017, Test F1: 0.8172
# Epoch [447/500], Loss: 0.1121
# Epoch [448/500], Loss: 0.1071, Train Accuracy: 0.9594, Train F1: 0.9297, Test Accuracy: 0.9028, Test F1: 0.8197
# Epoch [448/500], Loss: 0.1071
# Epoch [449/500], Loss: 0.1106, Train Accuracy: 0.9585, Train F1: 0.9283, Test Accuracy: 0.8989, Test F1: 0.8088
# Epoch [449/500], Loss: 0.1106
# Epoch [450/500], Loss: 0.1102, Train Accuracy: 0.9581, Train F1: 0.9266, Test Accuracy: 0.8997, Test F1: 0.8149
# Epoch [450/500], Loss: 0.1102
# Epoch [451/500], Loss: 0.1096, Train Accuracy: 0.9594, Train F1: 0.9300, Test Accuracy: 0.8989, Test F1: 0.8123
# Epoch [451/500], Loss: 0.1096
# Epoch [452/500], Loss: 0.1081, Train Accuracy: 0.9581, Train F1: 0.9275, Test Accuracy: 0.8967, Test F1: 0.8042
# Epoch [452/500], Loss: 0.1081
# Epoch [453/500], Loss: 0.1071, Train Accuracy: 0.9579, Train F1: 0.9264, Test Accuracy: 0.9000, Test F1: 0.8147
# Epoch [453/500], Loss: 0.1071
# Epoch [454/500], Loss: 0.1096, Train Accuracy: 0.9563, Train F1: 0.9248, Test Accuracy: 0.9008, Test F1: 0.8154
# Epoch [454/500], Loss: 0.1096
# Epoch [455/500], Loss: 0.1056, Train Accuracy: 0.9591, Train F1: 0.9292, Test Accuracy: 0.8972, Test F1: 0.8048
# Epoch [455/500], Loss: 0.1056
# Epoch [456/500], Loss: 0.1112, Train Accuracy: 0.9586, Train F1: 0.9276, Test Accuracy: 0.9033, Test F1: 0.8212
# Epoch [456/500], Loss: 0.1112
# Epoch [457/500], Loss: 0.1059, Train Accuracy: 0.9604, Train F1: 0.9316, Test Accuracy: 0.9019, Test F1: 0.8190
# Epoch [457/500], Loss: 0.1059
# Epoch [458/500], Loss: 0.1050, Train Accuracy: 0.9592, Train F1: 0.9293, Test Accuracy: 0.8961, Test F1: 0.8040
# Epoch [458/500], Loss: 0.1050
# Epoch [459/500], Loss: 0.1061, Train Accuracy: 0.9605, Train F1: 0.9307, Test Accuracy: 0.8997, Test F1: 0.8145
# Epoch [459/500], Loss: 0.1061
# Epoch [460/500], Loss: 0.1084, Train Accuracy: 0.9580, Train F1: 0.9274, Test Accuracy: 0.9000, Test F1: 0.8159
# Epoch [460/500], Loss: 0.1084
# Epoch [461/500], Loss: 0.1029, Train Accuracy: 0.9615, Train F1: 0.9339, Test Accuracy: 0.8956, Test F1: 0.8027
# Epoch [461/500], Loss: 0.1029
# Epoch [462/500], Loss: 0.1095, Train Accuracy: 0.9587, Train F1: 0.9281, Test Accuracy: 0.8997, Test F1: 0.8138
# Epoch [462/500], Loss: 0.1095
# Epoch [463/500], Loss: 0.1068, Train Accuracy: 0.9599, Train F1: 0.9305, Test Accuracy: 0.9000, Test F1: 0.8142
# Epoch [463/500], Loss: 0.1068
# Epoch [464/500], Loss: 0.1023, Train Accuracy: 0.9620, Train F1: 0.9342, Test Accuracy: 0.9000, Test F1: 0.8126
# Epoch [464/500], Loss: 0.1023
# Epoch [465/500], Loss: 0.1106, Train Accuracy: 0.9581, Train F1: 0.9274, Test Accuracy: 0.9008, Test F1: 0.8129
# Epoch [465/500], Loss: 0.1106
# Epoch [466/500], Loss: 0.1096, Train Accuracy: 0.9579, Train F1: 0.9266, Test Accuracy: 0.9017, Test F1: 0.8154
# Epoch [466/500], Loss: 0.1096
# Epoch [467/500], Loss: 0.1058, Train Accuracy: 0.9600, Train F1: 0.9304, Test Accuracy: 0.9008, Test F1: 0.8154
# Epoch [467/500], Loss: 0.1058
# Epoch [468/500], Loss: 0.1039, Train Accuracy: 0.9616, Train F1: 0.9331, Test Accuracy: 0.8997, Test F1: 0.8122
# Epoch [468/500], Loss: 0.1039
# Epoch [469/500], Loss: 0.1115, Train Accuracy: 0.9555, Train F1: 0.9228, Test Accuracy: 0.8975, Test F1: 0.8071
# Epoch [469/500], Loss: 0.1115
# Epoch [470/500], Loss: 0.1069, Train Accuracy: 0.9591, Train F1: 0.9289, Test Accuracy: 0.8994, Test F1: 0.8137
# Epoch [470/500], Loss: 0.1069
# Epoch [471/500], Loss: 0.1065, Train Accuracy: 0.9597, Train F1: 0.9305, Test Accuracy: 0.8970, Test F1: 0.8074
# Epoch [471/500], Loss: 0.1065
# Epoch [472/500], Loss: 0.1084, Train Accuracy: 0.9598, Train F1: 0.9299, Test Accuracy: 0.9006, Test F1: 0.8169
# Epoch [472/500], Loss: 0.1084
# Epoch [473/500], Loss: 0.1053, Train Accuracy: 0.9603, Train F1: 0.9317, Test Accuracy: 0.9000, Test F1: 0.8130
# Epoch [473/500], Loss: 0.1053
# Epoch [474/500], Loss: 0.1038, Train Accuracy: 0.9613, Train F1: 0.9327, Test Accuracy: 0.8989, Test F1: 0.8100
# Epoch [474/500], Loss: 0.1038
# Epoch [475/500], Loss: 0.1067, Train Accuracy: 0.9601, Train F1: 0.9307, Test Accuracy: 0.9006, Test F1: 0.8154
# Epoch [475/500], Loss: 0.1067
# Epoch [476/500], Loss: 0.1054, Train Accuracy: 0.9593, Train F1: 0.9296, Test Accuracy: 0.9011, Test F1: 0.8149
# Epoch [476/500], Loss: 0.1054
# Epoch [477/500], Loss: 0.1086, Train Accuracy: 0.9573, Train F1: 0.9261, Test Accuracy: 0.8975, Test F1: 0.8048
# Epoch [477/500], Loss: 0.1086
# Epoch [478/500], Loss: 0.1076, Train Accuracy: 0.9577, Train F1: 0.9260, Test Accuracy: 0.8992, Test F1: 0.8133
# Epoch [478/500], Loss: 0.1076
# Epoch [479/500], Loss: 0.1035, Train Accuracy: 0.9596, Train F1: 0.9301, Test Accuracy: 0.9000, Test F1: 0.8147
# Epoch [479/500], Loss: 0.1035
# Epoch [480/500], Loss: 0.1071, Train Accuracy: 0.9572, Train F1: 0.9260, Test Accuracy: 0.8948, Test F1: 0.7985
# Epoch [480/500], Loss: 0.1071
# Epoch [481/500], Loss: 0.1091, Train Accuracy: 0.9588, Train F1: 0.9277, Test Accuracy: 0.8983, Test F1: 0.8099
# Epoch [481/500], Loss: 0.1091
# Epoch [482/500], Loss: 0.1076, Train Accuracy: 0.9569, Train F1: 0.9256, Test Accuracy: 0.8964, Test F1: 0.8050
# Epoch [482/500], Loss: 0.1076
# Epoch [483/500], Loss: 0.1057, Train Accuracy: 0.9595, Train F1: 0.9296, Test Accuracy: 0.8967, Test F1: 0.8046
# Epoch [483/500], Loss: 0.1057
# Epoch [484/500], Loss: 0.1007, Train Accuracy: 0.9620, Train F1: 0.9335, Test Accuracy: 0.8970, Test F1: 0.8068
# Epoch [484/500], Loss: 0.1007
# Epoch [485/500], Loss: 0.0982, Train Accuracy: 0.9620, Train F1: 0.9339, Test Accuracy: 0.8997, Test F1: 0.8130
# Epoch [485/500], Loss: 0.0982
# Epoch [486/500], Loss: 0.1015, Train Accuracy: 0.9608, Train F1: 0.9321, Test Accuracy: 0.8975, Test F1: 0.8073
# Epoch [486/500], Loss: 0.1015
# Epoch [487/500], Loss: 0.1035, Train Accuracy: 0.9586, Train F1: 0.9281, Test Accuracy: 0.8986, Test F1: 0.8099
# Epoch [487/500], Loss: 0.1035
# Epoch [488/500], Loss: 0.1043, Train Accuracy: 0.9597, Train F1: 0.9300, Test Accuracy: 0.8989, Test F1: 0.8096
# Epoch [488/500], Loss: 0.1043
# Epoch [489/500], Loss: 0.1022, Train Accuracy: 0.9598, Train F1: 0.9301, Test Accuracy: 0.8997, Test F1: 0.8120
# Epoch [489/500], Loss: 0.1022
# Epoch [490/500], Loss: 0.1036, Train Accuracy: 0.9600, Train F1: 0.9306, Test Accuracy: 0.8992, Test F1: 0.8112
# Epoch [490/500], Loss: 0.1036
# Epoch [491/500], Loss: 0.0975, Train Accuracy: 0.9612, Train F1: 0.9326, Test Accuracy: 0.8972, Test F1: 0.8075
# Epoch [491/500], Loss: 0.0975
# Epoch [492/500], Loss: 0.0982, Train Accuracy: 0.9630, Train F1: 0.9353, Test Accuracy: 0.8983, Test F1: 0.8087
# Epoch [492/500], Loss: 0.0982
# Epoch [493/500], Loss: 0.1030, Train Accuracy: 0.9618, Train F1: 0.9333, Test Accuracy: 0.8986, Test F1: 0.8107
# Epoch [493/500], Loss: 0.1030
# Epoch [494/500], Loss: 0.1011, Train Accuracy: 0.9598, Train F1: 0.9302, Test Accuracy: 0.9000, Test F1: 0.8142
# Epoch [494/500], Loss: 0.1011
# Epoch [495/500], Loss: 0.1041, Train Accuracy: 0.9580, Train F1: 0.9272, Test Accuracy: 0.9011, Test F1: 0.8166
# Epoch [495/500], Loss: 0.1041
# Epoch [496/500], Loss: 0.1011, Train Accuracy: 0.9596, Train F1: 0.9299, Test Accuracy: 0.8983, Test F1: 0.8087
# Epoch [496/500], Loss: 0.1011
# Epoch [497/500], Loss: 0.1007, Train Accuracy: 0.9630, Train F1: 0.9356, Test Accuracy: 0.8994, Test F1: 0.8126
# Epoch [497/500], Loss: 0.1007
# Epoch [498/500], Loss: 0.0967, Train Accuracy: 0.9626, Train F1: 0.9354, Test Accuracy: 0.8992, Test F1: 0.8108
# Epoch [498/500], Loss: 0.0967
# Epoch [499/500], Loss: 0.0978, Train Accuracy: 0.9604, Train F1: 0.9312, Test Accuracy: 0.8983, Test F1: 0.8075
# Epoch [499/500], Loss: 0.0978
# Epoch [500/500], Loss: 0.0988, Train Accuracy: 0.9621, Train F1: 0.9341, Test Accuracy: 0.9000, Test F1: 0.8124
# Epoch [500/500], Loss: 0.0988

# %% [markdown]
# # Graph-Based Learning

# %%
data = NCFDataset(train_file=train_file, seed=SEED, col_user='conceptA', col_item='conceptB')
# Out:
# INFO:ncf.dataset:Indexing C:/Users/Luka/Documents/University/bachelor-project-prerequisite-learning/generated_data/akd_train_42.csv ...

# %%
data.n_users, data.n_items
# Out:
# (1384, 1600)

# %%
model = NCF(
    n_users=data.n_users, 
    n_items=data.n_items,
    model_type="NeuMF",
    n_factors=16,
    layer_sizes=[8,4],
    n_epochs=20,
    batch_size=256,
    learning_rate=0.001,
    verbose=20, 
    seed=SEED
)

# %%
# %%time

model.fit(data)
# Out:
# INFO:ncf.ncf:Epoch 20 [4.52s]: train_loss = 0.035806
# CPU times: total: 1min 4s
# Wall time: 1min 6s

# %%
THRESHOLD = 0.29

# %%
df = pd.read_csv(ENCODED_SPLIT_PATH)

# %%
df['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
predictions = [[row.conceptA, row.conceptB, model.predict(row.conceptA, row.conceptB)]
               for (_, row) in df.iterrows()]

predictions = pd.DataFrame(predictions, columns=['conceptA', 'conceptB', 'isPrerequisite_pred'])

predictions['isPrerequisite'] = df['isPrerequisite']
predictions['dataset'] = df['dataset']
predictions['_split_set'] = df['_split_set']
sorted_predictions = predictions.sort_values(by='isPrerequisite_pred', ascending=False)
sorted_predictions['pred'] = (sorted_predictions['isPrerequisite_pred'] >= THRESHOLD).astype(int)

# %%
sorted_predictions['isPrerequisite'].mean(), df['isPrerequisite'].mean(), sorted_predictions['isPrerequisite_pred'].mean()
# Out:
# (0.2868984820755733, 0.2868984820755733, 0.23067496558838732)

# %%
sorted_predictions['dataset'].value_counts()
# Out:
# dataset
# moocML     6712
# al_cpl     6529
# drive      2797
# moocDSA    2540
# Name: count, dtype: int64

# %%
df_moocML = sorted_predictions[sorted_predictions['dataset'] == 'moocML']
df_moocDSA = sorted_predictions[sorted_predictions['dataset'] == 'moocDSA']
df_drive = sorted_predictions[sorted_predictions['dataset'] == 'drive']
df_alcpl = sorted_predictions[sorted_predictions['dataset'] == 'al_cpl']

# %%
df_test = sorted_predictions[sorted_predictions['_split_set'] == 'test']

# %%
print(classification_report(df_test['isPrerequisite'], df_test['pred']))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.92      2652
#            1       0.88      0.65      0.75      1064
#
#     accuracy                           0.87      3716
#    macro avg       0.88      0.81      0.83      3716
# weighted avg       0.87      0.87      0.87      3716

# %%
print(precision_score(df_test['isPrerequisite'], df_test['pred']), recall_score(df_test['isPrerequisite'], df_test['pred']), f1_score(df_test['isPrerequisite'], df_test['pred']))
# Out:
# 0.879948914431673 0.6475563909774437 0.7460747157552788
